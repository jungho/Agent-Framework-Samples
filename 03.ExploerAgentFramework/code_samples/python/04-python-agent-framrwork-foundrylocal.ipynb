# %%
# ! pip install -r ../../../Installation/requirements.txt -U

# %%
import os

from dotenv import load_dotenv

# %%
from agent_framework import ChatMessage, Role
from agent_framework.openai import OpenAIChatClient

# %%
load_dotenv()
# Out:
# True

# %%
os.environ.get("FOUNDRYLOCAL_ENDPOINT")
# Out:
# 'http://127.0.0.1:57546/v1'

# %%
client = OpenAIChatClient(base_url= os.environ.get("FOUNDRYLOCAL_ENDPOINT"),api_key="nokey", model_id=os.environ.get("FOUNDRYLOCAL_MODEL_DEPLOYMENT_NAME"))

# %%
messages = [
        ChatMessage(role=Role.SYSTEM, text="You are a helpful assistant."),
        ChatMessage(role=Role.USER, text="Can you introduce yourself?")
    ]

# %%
response = await client.get_response(messages)

# %%
response.messages[0].text
# Out:
# '<think>\nOkay, the user just sent a message. Let me check what they need. The previous message from the assistant was a placeholder, so maybe the user is testing or needs help with something else. I should ask them to clarify what they need. Let me respond politely and request more details.\n</think>\n\nHello! How can I assist you today?'
