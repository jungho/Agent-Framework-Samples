# %%
# ! pip uninstall agent-framework-azure-ai -y

# %%
# ! pip install agent-framework-azure-ai -U

# %%
import os

from azure.identity.aio import AzureCliCredential
from azure.ai.projects.aio import AIProjectClient
from dotenv import load_dotenv

from agent_framework import ChatAgent
from agent_framework.azure import AzureAIAgentClient

# %%
load_dotenv()
# Out:
# True

# %%
async with (
        AzureCliCredential() as credential,
        AIProjectClient(endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"], credential=credential) as client,
    ):
        # Create an agent that will persist
        created_agent = await client.agents.as_agent(
            model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"], 
            name="TesDemo",
            instructions="You are a helpful weather agent.",
        )

        try:
            async with ChatAgent(
                # passing in the client is optional here, so if you take the agent_id from the portal
                # you can use it directly without the two lines above.
                chat_client=AzureAIAgentClient(project_client=client, agent_id=created_agent.id),
            ) as agent:
                result = await agent.run("Write a haiku about Agent Framework.")
                print(f"Result: {result}\n")
        finally:
             print("ok")
            # Clean up the agent manually
            # await client.agents.delete_agent(created_agent.id)
        # Create an agent that will persist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       1 async with (
#       2         AzureCliCredential() as credential,
#       3         AIProjectClient(endpoint=os.environ["AZURE_AI_PROJECT_ENDPOINT"], credential=credential) as client,
#       4     ):
#       5         # Create an agent that will persist
# ----> 6         created_agent = await client.agents.as_agent(
#       7             model=os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"],
#       8             name="TesDemo",
#       9             instructions="You are a helpful weather agent.",
#      10         )
#      12         try:
#      13             async with ChatAgent(
#      14                 # passing in the client is optional here, so if you take the agent_id from the portal
#      15                 # you can use it directly without the two lines above.
#      16                 chat_client=AzureAIAgentClient(project_client=client, agent_id=created_agent.id),
#      17             ) as agent:
#
# AttributeError: 'AgentsOperations' object has no attribute 'as_agent'
