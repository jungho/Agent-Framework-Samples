# %% [markdown]
# # ⚡ Concurrent Agent Workflows with GitHub Models (.NET)
#
# ## 📋 High-Performance Parallel Processing Tutorial
#
# This notebook demonstrates **concurrent workflow patterns** using the Microsoft Agent Framework for .NET and GitHub Models. You'll learn how to build high-performance, parallel processing workflows that maximize throughput by executing multiple AI agents simultaneously while maintaining coordination and data consistency.
#
# ## 🎯 Learning Objectives
#
# ### 🚀 **Concurrent Processing Fundamentals**
# - **Parallel Agent Execution**: Run multiple AI agents simultaneously for maximum performance
# - **Async/Await Patterns**: Leverage .NET's async programming model for efficient concurrency
# - **GitHub Models Integration**: Coordinate multiple concurrent calls to GitHub's AI model inference service
# - **Resource Management**: Efficiently manage AI model resources across concurrent operations
#
# ### 🏗️ **Advanced Concurrency Architecture**
# - **Task-Based Parallelism**: Use .NET Task Parallel Library for optimal concurrent execution
# - **Synchronization Patterns**: Coordinate concurrent agents while avoiding race conditions
# - **Load Balancing**: Distribute work efficiently across available concurrent processing capacity
# - **Fault Tolerance**: Handle individual agent failures without stopping the entire workflow
#
# ### 🏢 **Enterprise Concurrent Applications**
# - **High-Volume Document Processing**: Process multiple documents simultaneously
# - **Real-Time Content Analysis**: Concurrent analysis of incoming data streams
# - **Batch Processing Optimization**: Maximize throughput for large-scale data processing operations
# - **Multi-Modal Analysis**: Parallel processing of different content types and formats
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required NuGet Packages**
#
# Essential packages for high-performance concurrent workflows:
#
# ```xml
# <!-- Core AI Framework with Async Support -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Client Model Abstractions for API Communication -->
# <PackageReference Include="System.ClientModel" Version="1.6.1.0" />
#
# <!-- Azure Identity and Async LINQ for Advanced Operations -->
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
#
# <!-- Local Agent Framework References -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions with async support -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - GitHub Models integration with concurrency -->
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Concurrent Processing Considerations:**
# ```csharp
# // Configure for concurrent operations
# var clientOptions = new OpenAIClientOptions()
# {
#     Endpoint = new Uri(githubEndpoint),
#     // Configure connection pooling for concurrent requests
#     NetworkTimeout = TimeSpan.FromMinutes(5)
# };
# ```
#
# ### 🏗️ **Concurrent Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Workflow Input] --> B[Task Distribution]
#     B --> C[Concurrent Agent Pool]
#     C --> D[Agent Task 1]
#     C --> E[Agent Task 2]
#     C --> F[Agent Task 3]
#     C --> G[Agent Task N]
#
#     D --> H[Result Aggregation]
#     E --> H
#     F --> H
#     G --> H
#
#     H --> I[Synchronized Output]
#
#     J[GitHub Models API] --> D
#     J --> E
#     J --> F
#     J --> G
#
#     K[.NET Task Scheduler] --> C
# ```
#
# **Key Components:**
# - **Task Parallel Library**: .NET's built-in support for concurrent operations
# - **Agent Pool**: Multiple agent instances for parallel processing
# - **Result Aggregation**: Coordination and merging of concurrent agent results
# - **Synchronization Points**: Ensure data consistency across concurrent operations
#
# ## 🎨 **Concurrent Workflow Design Patterns**
#
# ### 🔍 **Parallel Research & Analysis**
# ```
# Research Topic → Concurrent Research Agents → Result Synthesis → Final Report
# ```
#
# ### 📊 **Multi-Source Data Processing**
# ```
# Data Sources → Parallel Processing Agents → Data Integration → Unified Output
# ```
#
# ### 🎭 **Content Generation Pipeline**
# ```
# Content Requirements → Concurrent Content Generators → Quality Review → Final Content
# ```
#
# ### 🔄 **Fan-Out/Fan-In Processing**
# ```
# Single Input → Multiple Concurrent Processors → Result Aggregation → Single Output
# ```
#
# ## 🏢 **Enterprise Performance Benefits**
#
# ### ⚡ **Throughput & Scalability**
# - **Linear Performance Scaling**: Add more concurrent agents to increase throughput
# - **Resource Utilization**: Maximum efficiency of available AI model capacity
# - **Reduced Processing Time**: Significant time reduction through parallel execution
# - **Elastic Scaling**: Dynamically adjust concurrent agent count based on workload
#
# ### 🛡️ **Reliability & Resilience**
# - **Fault Isolation**: Individual agent failures don't affect other concurrent operations
# - **Graceful Degradation**: System continues operating with reduced agent capacity
# - **Error Recovery**: Automatic retry mechanisms for failed concurrent operations
# - **Load Distribution**: Even distribution of work across available agents
#
# ### 📊 **Performance Monitoring**
# - **Concurrent Execution Metrics**: Track performance of all parallel operations
# - **Resource Usage Analytics**: Monitor CPU, memory, and network utilization
# - **Throughput Analysis**: Measure efficiency gains from concurrent processing
# - **Bottleneck Detection**: Identify and resolve performance constraints
#
# ### 🔧 **Development & Operations**
# - **Async Programming Model**: Leverage .NET's mature async/await patterns
# - **Task Coordination**: Built-in task management and coordination capabilities
# - **Exception Handling**: Comprehensive error handling for concurrent operations
# - **Debugging Support**: Visual Studio debugging tools for concurrent workflows
#
# Let's build high-performance concurrent AI workflows with .NET! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: System.ClientModel, 1.6.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.Workflows\bin\Debug\net9.0\Microsoft.Agents.Workflows.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;
using OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.Workflows;
using Microsoft.Agents.Workflows.Reflection;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id =  "gpt-4o";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
const string ResearcherAgentName = "Researcher-Agent";
const string ResearcherAgentInstructions = "You are my travel researcher, working with me to analyze the destination, list relevant attractions, and make detailed plans for each attraction.";

# %%
const string PlanAgentName = "Plan-Agent";
const string PlanAgentInstructions = "You are my travel planner, working with me to create a detailed travel plan based on the researcher's findings.";

# %%
AIAgent researcherAgent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:ResearcherAgentName,instructions:ResearcherAgentInstructions);
AIAgent plannerAgent  = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:PlanAgentName,instructions:PlanAgentInstructions);

# %%
public class ConcurrentStartExecutor() :
    ReflectingExecutor<ConcurrentStartExecutor>("ConcurrentStartExecutor"),
    IMessageHandler<string>
{
    /// <summary>
    /// Starts the concurrent processing by sending messages to the agents.
    /// </summary>
    /// <param name="message">The user message to process</param>
    /// <param name="context">Workflow context for accessing workflow services and adding events</param>
    /// <returns>A task representing the asynchronous operation</returns>
    public async ValueTask HandleAsync(string message, IWorkflowContext context)
    {
        // Broadcast the message to all connected agents. Receiving agents will queue
        // the message but will not start processing until they receive a turn token.
        await context.SendMessageAsync(new ChatMessage(ChatRole.User, message));
        // Broadcast the turn token to kick off the agents.
        await context.SendMessageAsync(new TurnToken(emitEvents: true));
    }
}

/// <summary>
/// Executor that aggregates the results from the concurrent agents.
/// </summary>
public class ConcurrentAggregationExecutor() :
    ReflectingExecutor<ConcurrentAggregationExecutor>("ConcurrentAggregationExecutor"),
    IMessageHandler<ChatMessage>
{
    private readonly List<ChatMessage> _messages = [];

    /// <summary>
    /// Handles incoming messages from the agents and aggregates their responses.
    /// </summary>
    /// <param name="message">The message from the agent</param>
    /// <param name="context">Workflow context for accessing workflow services and adding events</param>
    /// <returns>A task representing the asynchronous operation</returns>
    public async ValueTask HandleAsync(ChatMessage message, IWorkflowContext context)
    {
        this._messages.Add(message);

        if (this._messages.Count == 2)
        {
            var formattedMessages = string.Join(Environment.NewLine, this._messages.Select(m => $"{m.AuthorName}: {m.Text}"));
            await context.YieldOutputAsync(formattedMessages);
        }
    }
}

# %%
var startExecutor = new ConcurrentStartExecutor();
var aggregationExecutor = new ConcurrentAggregationExecutor();

# %%
var workflow = new WorkflowBuilder(startExecutor)
            .AddFanOutEdge(startExecutor, targets: [researcherAgent, plannerAgent])
            .AddFanInEdge(aggregationExecutor, sources: [researcherAgent, plannerAgent])
            .WithOutputFrom(aggregationExecutor)
            .Build();

# %%
        StreamingRun run = await InProcessExecution.StreamAsync(workflow, "Plan a trip to Seattle in December");
        await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
        {
            if (evt is WorkflowOutputEvent output)
            {
                Console.WriteLine($"Workflow completed with results:\n{output.Data}");
            }
        }
# Out:
# Workflow completed with results:
# Researcher-Agent: Seattle, known as the Emerald City, is a beautiful destination year-round, and December adds a magical winter charm to the city. Holiday lights, seasonal events, and cozy indoor attractions make it a fantastic time to visit. Here's a detailed guide to your December trip to Seattle.
#
# ---
#
# ### **Seattle in December Highlights**
# - **Weather**: Seattle in December is chilly and wet, with average temperatures ranging between 37°F (3°C) and 47°F (8°C). Rain is common, so bring waterproof clothing and sturdy shoes.
# - **Atmosphere**: Seattle embraces the festive spirit with Christmas lights, holiday markets, and winter events across the city.
#
# ---
#
# ## **High-Level Itinerary**
# **Day 1: Arrival and Exploring Downtown**
# - Afternoon: Pike Place Market
# - Evening: Seattle Great Wheel and Waterfront Fun
#
# **Day 2: Iconic Views & Museums**
# - Morning: Space Needle & Chihuly Garden and Glass
# - Afternoon: Museum of Pop Culture (MoPOP)
# - Evening: Winterfest at Seattle Center
#
# **Day 3: Seasonal Day Trips and Neighborhoods**
# - Morning: Leavenworth Christmas Village (optional day trip)
# - Afternoon: Fremont & Ballard Nicknack Shops/ Stay light-water
#
# ---
#
# ## **Detailed Plans for Each Attraction**
#
# ### **Day 1: Arrival and Exploring Downtown**
#
# #### **1. Pike Place Market**
# - **About**: One of Seattle's most famous landmarks, this historic market features fresh seafood, artisanal foods, and boutique stores. In December, the market is decked out in festive holiday décor.
# - **Must-Sees Here**:
#    - Watch the fishmongers throwing fish at the seafood stalls.
#    - Visit the world’s first Starbucks store.
#    - Explore the MarketFront area for stunning Elliott Bay views.
#    - Check out the festive crafts and foods at the seasonal Holiday Market.
# - **Tips**: Grab a warm drink from one of the nearby coffee shops – it can be chilly! Also, bring cash in case some smaller vendors don’t accept cards.
#
# #### **2. Seattle Great Wheel and Waterfront**
# - **About**: The Seattle Great Wheel is a 175-foot-high Ferris wheel offering beautiful views of the city skyline and Puget Sound, especially lovely at twilight.
# - **Tips**: Book a VIP gondola for an extra special experience!
# - **Nearby**: Stroll along the Waterfront Park for holiday lights and visit the nearby Seattle Aquarium.
# - **Evening Dining**: Consider dining at Elliott’s Oyster House for fresh seafood with waterfront views.
#
# ---
#
# ### **Day 2: Iconic Views & Immersive Museums**
#
# #### **1. Space Needle**
# - **About**: The Space Needle is Seattle’s signature landmark, offering breathtaking 360-degree views of the city, mountains, and waterways from its observation deck.
# - **Why December**: You might see snow-covered Mount Rainier on a clear day!
# - **Tips**: Visit in the morning when it’s less crowded and the skies are typically clearer.
#
# #### **2. Chihuly Garden and Glass**
# - **About**: Located next to the Space Needle, this immersive gallery and garden displays stunning glass art installations by Dale Chihuly.
# - **Highlights**: The glasshouse and outdoor garden sparkle beautifully during December’s low-light conditions.
# - **Time to Spend**: 1.5–2 hours
#
# #### **3. Museum of Pop Culture (MoPOP)**
# - **About**: A Seattle must-visit, this museum features interactive exhibits on music, sci-fi, gaming, and movies. It's housed in a strikingly unique building near Seattle Center.
# - **Winter Exhibits**: December often features special exhibitions and programs, particularly around the holidays.
# - **Tips**: Don’t miss the Nirvana and Jimi Hendrix Collections – two legendary musicians associated with the Pacific Northwest.
#
# #### **4. Winterfest at Seattle Center**
# - **About**: This annual holiday festival features ice skating, holiday-themed performances, and seasonal décor scattered around Seattle Center.
# - **When**: Runs through late December
# - **Tips**: Bundle up for the outdoor ice skating rink and enjoy hot chocolate from vendors.
#
# ---
#
# ### **Day 3: Seasonal Day Trip or Neighborhood Exploration**
#
# #### Option 1: **Leavenworth Christmas Village** (Day Trip)
# - **About**: A Bavarian-style village about 2 hours east of Seattle, Leavenworth transforms into a magical winter wonderland during the holiday season with millions of twinkling lights, Christmas carolers, and festive treats.
# - **Transportation**: Rent a car or book a guided tour from Seattle to Leavenworth.
# - **Highlights**: Strolling under the lights, hot mulled wine (glühwein), and sledding.
# - **Tips**: Dress warmly – temperatures here can drop quite a bit in December!
#
# #### Option 2: **Explore Fremont & Ballard**
# - **Fremont**:
#    - Visit quirky shops and the famous Fremont Troll under the bridge.
#    - Warm up at a cozy café like Milstead & Co.
# - **Ballard**:
#    - Walk along the Ballard Locks and fish ladder (you might spot a salmon!).
#    - Head to the Nordic Museum for a cultural experience.
#    - Explore breweries like Reuben’s Brews.
#
# ---
#
# ### Final Notes:
# - **Packing**: Waterproof outerwear, warm sweaters, sturdy shoes, and an umbrella are essential for making the most of December in Seattle's wet weather.
# - **Transportation**: Utilize the Link Light Rail and buses for efficient transportation. Ride-share apps like Uber/Lyft and car rentals are also available for travel flexibility.
# - **Dining**: Don’t miss the chance to try local seafood, including clam chowder from Ivar’s and oysters from The Walrus and the Carpenter in Ballard.
#
# Seattle in December is a perfect mix of cozy indoor attractions and festive outdoor experiences. With this guide, you're set to enjoy the best the city has to offer this holiday season. Let me know if you'd like additional recommendations or customized plans!
# Plan-Agent: Certainly! Seattle in December is a great place to enjoy the cozy charm of the Pacific Northwest. The holiday season brings festive decorations, seasonal events, and a relaxing vibe, perfect for sightseeing and exploring. Here’s a detailed 4-day plan for your trip, but feel free to adjust it based on your interests:
#
# ---
#
# ### **Day 1: Arrival & Exploring Downtown**
# #### Morning:
# - **Arrive in Seattle:** Depending on where you’re flying from, land at SeaTac International Airport. Arrange transportation to your accommodation. If you’re staying downtown, consider booking a central hotel like the Fairmont Olympic Hotel, The Westin Seattle, or an Airbnb near Pike Place Market.
# - **Settle in and fuel up:** Have brunch at **Tilikum Place Café**, known for their Dutch pancakes and cozy vibe.
#
# #### Afternoon:
# - **Pike Place Market:** Start by wandering through Seattle’s iconic public market. Don't miss the flying fish market, fresh produce, and artisanal stalls.
#   - Visit the **Gum Wall** (an unusual but popular photo op).
#   - Stop by the **Original Starbucks** (at 1912 Pike Place), the first-ever Starbucks location.
# - **Seattle Aquarium:** If you’re interested in marine life, the nearby aquarium on Elliott Bay is family-friendly.
#
# #### Evening:
# - **Dinner with a view:** Head to **The Pink Door**, an Italian-American restaurant offering delicious food and a warm, inviting environment. It’s near Pike Place and often has live performances.
# - Stroll along the **Seattle Waterfront** lit up with holiday lights and breathtaking views of Puget Sound.
#
# ---
#
# ### **Day 2: Iconic Attractions**
# #### Morning:
# - **Breakfast:** Try **Tenth & Blake**, a cozy café downtown.
# - **Space Needle:** Start your day by visiting this iconic Seattle landmark. Take in the panoramic views of the city, Puget Sound, Mount Rainier, and, on clear days, the Olympic Mountains.
# - **Chihuly Garden and Glass:** Located right next to the Space Needle, this stunning exhibit features colorful and imaginative glass art installations.
#
# #### Afternoon:
# - **MoPOP (Museum of Pop Culture):** After Chihuly, walk over to this unique, architecture-worthy museum. Immerse yourself in exhibits about music, sci-fi, pop culture, and even video games.
# - **Lunch options nearby:** Try **Collections Café** near the Space Needle or head back downtown for a fresh seafood lunch.
#
# #### Evening:
# - **Holiday Magic:** December in Seattle comes alive with festive lights and activities. Head to **Westlake Center Plaza** to shop seasonal markets or take a spin on the holiday carousel.
# - **Dinner:** Dine at **Lola**, a popular Tom Douglas restaurant with Mediterranean-inspired dishes.
#
# ---
#
# ### **Day 3: Outdoor & Relaxation**
# #### Morning:
# - **Breakfast:** Treat yourself to pastries at **Macrina Bakery & Café**.
# - **Discovery Park:** Bundle up and enjoy a winter walk through Seattle’s largest green space. Stroll to the **West Point Lighthouse** for picturesque views of the water and mountains.
#
# #### Afternoon:
# - **Lunch in Ballard:** Head to the vibrant Ballard neighborhood and lunch at **The Whale Wins** or enjoy a burger at **Uneeda Burger**.
# - **Ballard Locks and Fish Ladder:** A fascinating spot to watch boats pass from Lake Union to Puget Sound and see salmon climbing the fish ladder (though December isn't peak migration season).
# - **Explore Fremont & Gas Works Park:** Visit quirky Fremont with its shops, breweries, and street art (including the famous Fremont Troll). Cap it off with a visit to Gas Works Park for scenic views of the city skyline.
#
# #### Evening:
# - **Dinner in Fremont or Capitol Hill:** Head to Capitol Hill’s trendy food spots, like **Rumba** (Caribbean vibes) or **Mezcaleria Oaxaca**.
#
# ---
#
# ### **Day 4: Local Gems & Departure**
# #### Morning:
# - **Coffee Crawl in Capitol Hill:** Start your day by exploring Seattle’s coffee scene. Visit **Espresso Vivace** or **Victrola Coffee Roasters** for the perfect cup.
# - **Volunteer Park Conservatory:** For a peaceful escape, visit this lush Victorian-style greenhouse, perfect for plant lovers.
# - **Museum or shopping options:**
#   - If it’s rainy, consider the **Seattle Art Museum** or the **Wing Luke Museum** (dedicated to Seattle’s Asian-American culture).
#   - Alternatively, spend some time shopping in **Pioneer Square** or peruse independent bookstores like **Elliott Bay Book Company**.
#
# #### Afternoon:
# - **Lunch:** Have a final meal at **The London Plane**, a rustic café and bakery known for its fresh fare.
# - Head back to your hotel to pack and check out. Depending on your flight time, you may have some extra hours for a final stroll.
#
# #### Evening:
# - **Airport transfer:** Arrange for a ride back to SeaTac Airport (Link Light Rail, rideshare, or shuttle) and bid farewell to Seattle!
#
# ---
#
# ### **Packing Tips for December in Seattle:**
# - **Layers:** December is chilly (highs around 45°F / 7°C), so pack warm layers, sweaters, and a waterproof jacket.
# - **Footwear:** Bring comfortable, waterproof shoes; it’s often rainy!
# - **Umbrella:** A compact umbrella is handy, though locals often brave the rain without one.
#
# ### Bonus Tips:
# - **Holiday Events:** Look into seasonal events like the Seattle Christmas Ship Festival or Winterfest at Seattle Center.
# - **Public Transport:** Seattle’s Link Light Rail and buses are convenient for getting around without a car.
# - **Day Trips:** If you have extra time, consider a ferry ride to Bainbridge Island or explore Leavenworth (a Bavarian-themed town) for an enchanting holiday vibe.
#
# Let me know if you’d like any modifications, additional activities, or suggestions!
