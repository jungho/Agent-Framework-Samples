# %% [markdown]
# # ⏩ Sequential Agent Workflows with GitHub Models (.NET)
#
# ## 📋 Advanced Sequential Processing Tutorial
#
# This notebook demonstrates **sequential workflow patterns** using the Microsoft Agent Framework for .NET and GitHub Models. You'll learn how to build sophisticated, step-by-step processing pipelines where agents execute in a specific order, with each stage building upon the results of the previous stage.
#
# ## 🎯 Learning Objectives
#
# ### 🔄 **Sequential Processing Architecture**
# - **Linear Workflow Design**: Create step-by-step processing pipelines with clear dependencies
# - **State Management**: Maintain context and data flow across sequential workflow stages
# - **GitHub Models Integration**: Leverage GitHub's AI models in multi-stage .NET workflows
# - **Enterprise Pipeline Patterns**: Build production-ready sequential processing systems
#
# ### 🏗️ **Advanced Sequential Patterns**
# - **Stage-Gate Processing**: Implement validation checkpoints between workflow stages
# - **Context Preservation**: Maintain state and accumulated knowledge across all stages
# - **Error Propagation**: Handle failures gracefully in sequential processing chains
# - **Performance Optimization**: Efficient sequential execution with minimal overhead
#
# ### 🏢 **Enterprise Sequential Applications**
# - **Document Processing Pipeline**: Multi-stage document analysis, transformation, and validation
# - **Quality Assurance Workflows**: Sequential review, validation, and approval processes
# - **Content Production Pipeline**: Research → Writing → Editing → Review → Publishing
# - **Business Process Automation**: Multi-step business workflows with clear stage dependencies
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required NuGet Packages**
#
# Essential packages for .NET sequential workflows:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Client Model Abstractions -->
# <PackageReference Include="System.ClientModel" Version="1.6.1.0" />
#
# <!-- Azure Identity and Async LINQ Support -->
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
#
# <!-- Local Agent Framework References -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - GitHub Models integration -->
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Configuration Management:**
# ```csharp
# // Load environment variables securely
# Env.Load("../../../.env");
# var githubToken = Environment.GetEnvironmentVariable("GITHUB_TOKEN");
# var githubEndpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT");
# var modelId = Environment.GetEnvironmentVariable("GITHUB_MODEL_ID");
# ```
#
# ### 🏗️ **Sequential Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Initial Input] --> B[Stage 1: Analysis Agent]
#     B --> C[Checkpoint 1]
#     C --> D[Stage 2: Processing Agent]
#     D --> E[Checkpoint 2]
#     E --> F[Stage 3: Validation Agent]
#     F --> G[Final Output]
#
#     H[State Context] --> B
#     H --> D
#     H --> F
#
#     I[GitHub Models API] --> B
#     I --> D
#     I --> F
# ```
#
# **Key Components:**
# - **Sequential Agents**: Specialized agents for each processing stage
# - **State Context**: Maintains accumulated data and decisions across stages
# - **Checkpoints**: Validation points between stages to ensure quality and consistency
# - **GitHub Models Client**: Consistent AI model access across all workflow stages
#
# ## 🎨 **Sequential Workflow Design Patterns**
#
# ### 📝 **Document Processing Pipeline**
# ```
# Raw Document → Content Extraction → Analysis → Validation → Structured Output
# ```
#
# ### 🎯 **Content Creation Workflow**
# ```
# Brief/Requirements → Research → Content Creation → Review → Final Polish
# ```
#
# ### 🔍 **Quality Assurance Pipeline**
# ```
# Initial Review → Technical Validation → Compliance Check → Final Approval
# ```
#
# ### 💼 **Business Intelligence Workflow**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ## 🏢 **Enterprise Sequential Benefits**
#
# ### 🎯 **Reliability & Quality**
# - **Deterministic Processing**: Consistent, repeatable outcomes through structured stages
# - **Quality Gates**: Validation checkpoints ensure quality at each stage
# - **Error Isolation**: Problems in one stage don't propagate to subsequent stages
# - **Audit Trails**: Complete tracking of decisions and transformations at each stage
#
# ### 📈 **Scalability & Performance**
# - **Modular Design**: Each stage can be optimized independently
# - **Resource Management**: Efficient allocation of AI model resources across stages
# - **State Optimization**: Minimal state transfer between stages for optimal performance
# - **Parallel Stage Groups**: Multiple sequential workflows can run in parallel
#
# ### 🔒 **Security & Compliance**
# - **Stage-Level Security**: Different security policies for different processing stages
# - **Data Validation**: Ensure data integrity and compliance at each checkpoint
# - **Access Control**: Granular permissions for different workflow stages
# - **Regulatory Compliance**: Meet regulatory requirements through structured processing
#
# ### 📊 **Monitoring & Analytics**
# - **Stage-Level Metrics**: Performance monitoring for each workflow stage
# - **Bottleneck Identification**: Identify and optimize slow stages
# - **Quality Metrics**: Track quality and success rates at each stage
# - **Process Optimization**: Continuous improvement based on stage-level analytics
#
# Let's build robust sequential AI processing pipelines! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: System.ClientModel, 1.6.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.Workflows\bin\Debug\net9.0\Microsoft.Agents.AI.Workflows.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;
using OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id =  "gpt-4o";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

var imgPath ="../imgs/home.png";

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
const string SalesAgentName = "Sales-Agent";
const string SalesAgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
const string PriceAgentName = "Price-Agent";
const string PriceAgentInstructions = @"You are a furniture pricing specialist and budget consultant. Your responsibilities include:
        1. Analyze furniture items and provide realistic price ranges based on quality, brand, and market standards
        2. Break down pricing by individual furniture pieces
        3. Provide budget-friendly alternatives and premium options
        4. Consider different price tiers (budget, mid-range, premium)
        5. Include estimated total costs for room setups
        6. Suggest where to find the best deals and shopping recommendations
        7. Factor in additional costs like delivery, assembly, and accessories
        8. Provide seasonal pricing insights and best times to buy
        Always format your response with clear price breakdowns and explanations for the pricing rationale.";

# %%
const string QuoteAgentName = "Quote-Agent";
const string QuoteAgentInstructions = @"You are a assistant that create a quote for furniture purchase.
        1. Create a well-structured quote document that includes:
        2. A title page with the document title, date, and client name
        3. An introduction summarizing the purpose of the document
        4. A summary section with total estimated costs and recommendations
        5. Use clear headings, bullet points, and tables for easy readability
        6. All quotes are presented in markdown form";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
imageBytes
# Out:
# <div class="dni-plaintext"><pre>[ 137, 80, 78, 71, 13, 10, 26, 10, 0, 0, 0, 13, 73, 72, 68, 82, 0, 0, 3, 142 ... (823194 more) ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
AIAgent salesagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:SalesAgentName,instructions:SalesAgentInstructions);
AIAgent priceagent  = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:PriceAgentName,instructions:PriceAgentInstructions);
AIAgent quoteagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:QuoteAgentName,instructions:QuoteAgentInstructions);

# %%
var workflow = new WorkflowBuilder(salesagent)
            .AddEdge(salesagent,priceagent)
            .AddEdge(priceagent, quoteagent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new DataContent(imageBytes, "image/png"),new TextContent("Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture.Finally Output generates a quotation") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Certainly! Let me provide a breakdown of the furniture pieces visible in this image, along with their estimated prices based on modern furniture offerings. Please note that these prices are approximate and can vary depending on the manufacturer and quality of the product.
#
# ### Furniture Items Observed in the Image:
# 1. **TV Console/Media Stand**
#    - Description: A low wood-finish TV console on legs with storage drawers/cabinets.
#    - Price Estimate: **$300 - $500**
#
# 2. **White Sofa**
#    - Description: A clean-lined, white, three-seater sofa with a mix of light and dark blue cushions and throw pillows.
#    - Price Estimate: **$600 - $800**
#
# 3. **Round Coffee Table**
#    - Description: A small, light wood coffee table with rounded edges and angled legs.
#    - Price Estimate: **$150 - $250**
#
# 4. **Accent Chair**
#    - Description: A navy blue fabric wingback accent chair with a modern flair and angled legs.
#    - Price Estimate: **$200 - $400**
#
# 5. **Floor Lamp/Game Table Lamp (Next to Fabric Chair)**
#    - Description: A tall, slim lamp with a tripod-style or metallic stand and decorative hanging features.
#    - Price Estimate: **$100 - $200**
#
# 6. **Pendant Light Fixture (Ceiling)**
#    - Description: Modern, industrial-chic chandelier with multiple round glass globes.
#    - Price Estimate: **$250 - $400**
#
# 7. **Side Table (Next to Sofa)**
#    - Description: Small, light-colored side table with a clean, modern design to hold a lamp and accessories.
#    - Price Estimate: **$100 - $200**
#
# 8. **Curtains/Window Drapes**
#    - Description: Dual-layer curtains (sheer white fabric and heavy gray fabric).
#    - Price Estimate: **$200 - $350**
#
# 9. **Throw Pillows**
#    - Description: Assorted mix of light and dark blue cushions and geometric-patterned throw pillows.
#    - Price Estimate: **$15 - $30 per pillow**
#    - Quantity: Around 6 pillows = **$90 - $180**
#
# 10. **Wall Art (Deer Print over the Sofa)**
#     - Description: Thin-framed artwork with a deer motif, adding a naturalistic touch to the space.
#     - Price Estimate: **$50 - $100**
#
# ---
#
# ### Quotation:
# | **Furniture**          | **Estimated Price (USD)** |
# |-------------------------|---------------------------|
# | TV Console/Media Stand  | $400                     |
# | White Sofa              | $700                     |
# | Round Coffee Table      | $200                     |
# | Accent Chair            | $300                     |
# | Floor Lamp              | $150                     |
# | Pendant Light Fixture   | $300                     |
# | Side Table              | $150                     |
# | Curtains/Drapes         | $300                     |
# | Throw Pillows (6)       | $120                     |
# | Wall Art                | $75                      |
# | **Total Estimated Cost** | **$2695**                |
#
# This estimate provides a guideline for purchasing similar furniture. If you'd like, I could assist you in sourcing these pieces from specific retailers or suggest alternative options based on your budget or preferences!Certainly, let's break down the furniture pricing and provide detailed insights to help you make informed decisions.
#
# ---
#
# ## **Furniture Price Breakdown**
#
# ### 1. TV Console/Media Stand
# - **Description**: Low wood-finish console with storage drawers; sleek and minimal design.
# - **Price Tiers**:
#   - **Budget**: $150-$300 (Simple particle board, laminate finish)
#   - **Mid-Range**: $300-$500 (Solid wood or engineered wood, better craftsmanship)
#   - **Premium**: $600-$1,200+ (Designer brands, hardwood/solid wood, unique designs)
# - **Best Brands**: IKEA (Budget), West Elm (Mid-Range), Crate & Barrel (Premium)
#
# ---
#
# ### 2. White Sofa
# - **Description**: Three-seater with clean lines and accent cushions.
# - **Price Tiers**:
#   - **Budget**: $200-$600 (Polyester upholstery, foam cushions, basic frame)
#   - **Mid-Range**: $600-$1,200 (Performance fabric, memory foam seating, solid frame)
#   - **Premium**: $1,500-$4,000 (Designer brands, high-end leather, or wool blend)
# - **Best Brands**: Wayfair (Budget), Article (Mid-Range), Design Within Reach (Premium)
#
# ---
#
# ### 3. Round Coffee Table
# - **Description**: Light wood construction with simple modern design elements.
# - **Price Tiers**:
#   - **Budget**: $50-$150 (Particle board or MDF, laminate finishes)
#   - **Mid-Range**: $150-$500 (Solid wood or engineered woods with intricate designs)
#   - **Premium**: $500-$1,200+ (Custom designs, branded pieces, hand-crafted detailing)
# - **Best Brands**: Target and Living Spaces (Budget), Poly & Bark (Mid-Range), CB2 (Premium)
#
# ---
#
# ### 4. Accent Chair
# - **Description**: Stylish navy blue wingback chair with angled wooden legs.
# - **Price Tiers**:
#   - **Budget**: $100-$250 (Basic fabric upholstery, lightweight wood or metal frame)
#   - **Mid-Range**: $300-$500 (Performance fabric, ergonomic shape, durable frame)
#   - **Premium**: $600-$1,500+ (Designer collections, velvet/leather materials, luxury builds)
# - **Best Brands**: Amazon (Budget), Joybird (Mid-Range), Restoration Hardware (Premium)
#
# ---
#
# ### 5. Floor Lamp
# - **Description**: Slim, tripod-style standing lamp with a contemporary finish.
# - **Price Tiers**:
#   - **Budget**: $30-$100 (Basic metal or plastic build, generic design)
#   - **Mid-Range**: $100-$300 (Brushed metal, unique designs)
#   - **Premium**: $300-$800+ (Custom designs, advanced lighting mechanisms)
# - **Best Brands**: Target and Overstock (Budget), Wayfair (Mid-Range), Lumens (Premium)
#
# ---
#
# ### 6. Pendant Light Fixture
# - **Description**: Ceiling fixture with glass globes and metallic accents.
# - **Price Tiers**:
#   - **Budget**: $100-$250 (Basic glass and metal materials, simple shapes)
#   - **Mid-Range**: $300-$600 (Statement designs, durable construction)
#   - **Premium**: $700-$1,500+ (Designer lighting with intricate detailing)
# - **Best Brands**: IKEA (Budget), West Elm (Mid-Range), Anthropologie (Premium)
#
# ---
#
# ### 7. Curtains/Window Drapes
# - **Description**: Dual-layer sheer fabric and heavy blackout drapes.
# - **Price Tiers**:
#   - **Budget**: $75-$200 (Polyester blend, basic curtain rods, solid colors)
#   - **Mid-Range**: $200-$500 (Linen/cotton blend, decorative hardware options)
#   - **Premium**: $500-$1,000+ (Custom designs, luxury fabrics like silk/velvet)
# - **Best Brands**: Amazon (Budget), Pottery Barn (Mid-Range), The Shade Store (Premium)
#
# ---
#
# ### 8. Throw Pillows
# - **Description**: Patterned & solid blue accent pillows.
# - **Price Tiers**:
#   - **Budget**: $15-$30/pillow (Basic polyester, simple prints)
#   - **Mid-Range**: $40-$80/pillow (Designer covers, foam or feather filling)
#   - **Premium**: $100-$200/pillow (Handcrafted or limited-edition styles, high-quality fill & fabrics)
# - **Best Brands**: IKEA and Target (Budget), Etsy for unique pillows (Mid-Range), high-end stores like Serena & Lily (Premium)
#
# ---
#
# ### 9. Wall Art
# - **Description**: Framed deer print, naturalistic and minimal design.
# - **Price Tiers**:
#   - **Budget**: $25-$75 (Pre-framed art prints from budget stores)
#   - **Mid-Range**: $100-$300 (Custom-sized prints, better finishes)
#   - **Premium**: $500-$1,500+ (Gallery-quality or artist originals)
# - **Best Brands**: Amazon and Walmart (Budget), Society6 (Mid-Range), Local galleries or custom framing shops (Premium).
#
# ---
#
# ## **Estimated Total Costs for Room Setup**
#
# | **Room Setup Tier**     | **Estimated Costs (USD)**           |
# |-------------------------|-------------------------------------|
# | **Budget**              | $1,500-$2,800                      |
# | **Mid-Range**           | $3,000-$5,500                      |
# | **Premium**             | $6,000-$10,000+                    |
#
# ---
#
# ## **Additional Costs to Factor In**:
# 1. **Delivery**: $50-$200 (Standard delivery fees; premium delivery includes in-home service and item protection).
# 2. **Assembly**: $0-$150 per item (Self-assembly vs. professional services).
# 3. **Accessories**: $100-$300 for rugs, extra decor pieces, or vase sets.
#
# ---
#
# ## **Seasonal Pricing Insights**
# 1. **Best Seasonal Shopping Periods**:
#    - **Black Friday/Cyber Monday (November)**: Biggest markdowns on furniture, often up to 70% off.
#    - **End-of-season clearance (January/July)**: Retailers clear old stock as new designs roll in.
#    - **Spring Discounts (March-April)**: Great deals on outdoor furniture and lighter fabrics.
#
# ---
#
# ## **Shopping Recommendations**:
# 1. **Budget**: IKEA, Walmart, Target, and Amazon are ideal.
# 2. **Mid-Range**: West Elm, Article, Joybird, and Wayfair offer great quality without being too expensive.
# 3. **Premium**: RH (Restoration Hardware), Design Within Reach, and high-end European retailers like BoConcept.
#
# Let me know if you'd like further customizations, layout ideas, or alternative suggestions for any items!Sure, here's a fully structured quote document presented in markdown format:
#
# ---
#
# # **Furniture Purchase Quote**
# **Date**: October 12, 2023
# **Client Name**: [Client Name]
#
# ---
#
# ## **Introduction**
#
# This document serves as a detailed quotation for the purchase of furniture items tailored to your design preferences and budget requirements. Each item includes descriptions, pricing tiers, and brand recommendations to provide the best options. The total estimated costs and shopping recommendations are included at the end to facilitate decision-making.
#
# ---
#
# ## **Furniture Quote**
#
# | **Item**                 | **Description**                                | **Price Range (USD)**      | **Best Brands**                  |
# |--------------------------|----------------------------------------------|---------------------------|-----------------------------------|
# | **TV Console/Media Stand** | Low wood-finish console with storage drawers | $150 - $1,200+             | IKEA, West Elm, Crate & Barrel   |
# | **White Sofa**           | Three-seater with clean lines and accent cushions | $200 - $4,000+             | Wayfair, Article, Design Within Reach |
# | **Round Coffee Table**   | Light wood construction with modern design    | $50 - $1,200+              | Target, Poly & Bark, CB2         |
# | **Accent Chair**         | Stylish navy blue chair with angled wooden legs | $100 - $1,500+             | Amazon, Joybird, Restoration Hardware |
# | **Floor Lamp**           | Slim, tripod-style standing lamp             | $30 - $800+                | Target, Wayfair, Lumens          |
# | **Pendant Light Fixture** | Ceiling fixture with glass globes and metallic accents | $100 - $1,500+             | IKEA, West Elm, Anthropologie    |
# | **Curtains/Drapes**      | Dual-layer sheer fabric and heavy blackout drapes | $75 - $1,000+              | Amazon, Pottery Barn, The Shade Store |
# | **Throw Pillows**        | Patterned & solid blue accent pillows        | $15 - $200/pillow          | IKEA, Etsy, Serena & Lily        |
# | **Wall Art**             | Framed deer print, naturalistic and minimal design | $25 - $1,500+              | Amazon, Society6, Local Galleries|
#
# ---
#
# ## **Summary of Total Estimated Costs**
#
# | **Room Setup Tier** | **Estimated Costs (USD)**      |
# |---------------------|-------------------------------|
# | **Budget**          | $1,500-$2,800                |
# | **Mid-Range**       | $3,000-$5,500                |
# | **Premium**         | $6,000-$10,000+              |
#
# **Additional Costs**:
# - **Delivery**: $50-$200
# - **Assembly**: $0-$150 per item
# - **Accessories**: $100-$300 for rugs, vase sets, and small decor items
#
# ---
#
# ## **Recommendations**
#
# ### **Budget-Friendly**
# - Focus on IKEA, Walmart, Target, and Amazon for affordable yet functional options.
# - Opt for self-assembly to reduce costs.
#
# ### **Mid-Range Quality**
# - Consider brands like West Elm, Wayfair, Joybird, and Article that offer a balance between style and price.
# - Take advantage of seasonal sales such as Black Friday to maximize savings.
#
# ### **Premium Design**
# - Explore Restoration Hardware, Design Within Reach, or BoConcept for luxurious and high-quality choices.
# - Invest in designer or custom pieces for a truly personalized space.
#
# ---
#
# ## **Seasonal Pricing Insights**
#
# - **Black Friday/Cyber Monday (November)**: Up to 70% discounts on furniture.
# - **Clearance Sales (January and July)**: Retailers reduce prices to make way for new collections.
# - **Spring Specials (March-April)**: Discounts on light fabrics and outdoor options.
#
# ---
#
# Thank you for considering this quotation document. Should you require additional customization or have specific requests, please feel free to reach out.
#
# ---
