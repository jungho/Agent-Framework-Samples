# %% [markdown]
# # ⏩ Sequential Agent Workflows with GitHub Models (.NET)
#
# ## 📋 Advanced Sequential Processing Tutorial
#
# This notebook demonstrates **sequential workflow patterns** using the Microsoft Agent Framework for .NET and GitHub Models. You'll learn how to build sophisticated, step-by-step processing pipelines where agents execute in a specific order, with each stage building upon the results of the previous stage.
#
# ## 🎯 Learning Objectives
#
# ### 🔄 **Sequential Processing Architecture**
# - **Linear Workflow Design**: Create step-by-step processing pipelines with clear dependencies
# - **State Management**: Maintain context and data flow across sequential workflow stages
# - **GitHub Models Integration**: Leverage GitHub's AI models in multi-stage .NET workflows
# - **Enterprise Pipeline Patterns**: Build production-ready sequential processing systems
#
# ### 🏗️ **Advanced Sequential Patterns**
# - **Stage-Gate Processing**: Implement validation checkpoints between workflow stages
# - **Context Preservation**: Maintain state and accumulated knowledge across all stages
# - **Error Propagation**: Handle failures gracefully in sequential processing chains
# - **Performance Optimization**: Efficient sequential execution with minimal overhead
#
# ### 🏢 **Enterprise Sequential Applications**
# - **Document Processing Pipeline**: Multi-stage document analysis, transformation, and validation
# - **Quality Assurance Workflows**: Sequential review, validation, and approval processes
# - **Content Production Pipeline**: Research → Writing → Editing → Review → Publishing
# - **Business Process Automation**: Multi-step business workflows with clear stage dependencies
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required NuGet Packages**
#
# Essential packages for .NET sequential workflows:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Client Model Abstractions -->
# <PackageReference Include="System.ClientModel" Version="1.6.1.0" />
#
# <!-- Azure Identity and Async LINQ Support -->
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
#
# <!-- Local Agent Framework References -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - GitHub Models integration -->
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Configuration Management:**
# ```csharp
# // Load environment variables securely
# Env.Load("../../../.env");
# var githubToken = Environment.GetEnvironmentVariable("GITHUB_TOKEN");
# var githubEndpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT");
# var modelId = Environment.GetEnvironmentVariable("GITHUB_MODEL_ID");
# ```
#
# ### 🏗️ **Sequential Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Initial Input] --> B[Stage 1: Analysis Agent]
#     B --> C[Checkpoint 1]
#     C --> D[Stage 2: Processing Agent]
#     D --> E[Checkpoint 2]
#     E --> F[Stage 3: Validation Agent]
#     F --> G[Final Output]
#
#     H[State Context] --> B
#     H --> D
#     H --> F
#
#     I[GitHub Models API] --> B
#     I --> D
#     I --> F
# ```
#
# **Key Components:**
# - **Sequential Agents**: Specialized agents for each processing stage
# - **State Context**: Maintains accumulated data and decisions across stages
# - **Checkpoints**: Validation points between stages to ensure quality and consistency
# - **GitHub Models Client**: Consistent AI model access across all workflow stages
#
# ## 🎨 **Sequential Workflow Design Patterns**
#
# ### 📝 **Document Processing Pipeline**
# ```
# Raw Document → Content Extraction → Analysis → Validation → Structured Output
# ```
#
# ### 🎯 **Content Creation Workflow**
# ```
# Brief/Requirements → Research → Content Creation → Review → Final Polish
# ```
#
# ### 🔍 **Quality Assurance Pipeline**
# ```
# Initial Review → Technical Validation → Compliance Check → Final Approval
# ```
#
# ### 💼 **Business Intelligence Workflow**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ## 🏢 **Enterprise Sequential Benefits**
#
# ### 🎯 **Reliability & Quality**
# - **Deterministic Processing**: Consistent, repeatable outcomes through structured stages
# - **Quality Gates**: Validation checkpoints ensure quality at each stage
# - **Error Isolation**: Problems in one stage don't propagate to subsequent stages
# - **Audit Trails**: Complete tracking of decisions and transformations at each stage
#
# ### 📈 **Scalability & Performance**
# - **Modular Design**: Each stage can be optimized independently
# - **Resource Management**: Efficient allocation of AI model resources across stages
# - **State Optimization**: Minimal state transfer between stages for optimal performance
# - **Parallel Stage Groups**: Multiple sequential workflows can run in parallel
#
# ### 🔒 **Security & Compliance**
# - **Stage-Level Security**: Different security policies for different processing stages
# - **Data Validation**: Ensure data integrity and compliance at each checkpoint
# - **Access Control**: Granular permissions for different workflow stages
# - **Regulatory Compliance**: Meet regulatory requirements through structured processing
#
# ### 📊 **Monitoring & Analytics**
# - **Stage-Level Metrics**: Performance monitoring for each workflow stage
# - **Bottleneck Identification**: Identify and optimize slow stages
# - **Quality Metrics**: Track quality and success rates at each stage
# - **Process Optimization**: Continuous improvement based on stage-level analytics
#
# Let's build robust sequential AI processing pipelines! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: System.ClientModel, 1.6.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.Workflows\bin\Debug\net9.0\Microsoft.Agents.AI.Workflows.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;
using OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.AI.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id =  "gpt-4o";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

var imgPath ="../imgs/home.png";

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
const string SalesAgentName = "Sales-Agent";
const string SalesAgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
const string PriceAgentName = "Price-Agent";
const string PriceAgentInstructions = @"You are a furniture pricing specialist and budget consultant. Your responsibilities include:
        1. Analyze furniture items and provide realistic price ranges based on quality, brand, and market standards
        2. Break down pricing by individual furniture pieces
        3. Provide budget-friendly alternatives and premium options
        4. Consider different price tiers (budget, mid-range, premium)
        5. Include estimated total costs for room setups
        6. Suggest where to find the best deals and shopping recommendations
        7. Factor in additional costs like delivery, assembly, and accessories
        8. Provide seasonal pricing insights and best times to buy
        Always format your response with clear price breakdowns and explanations for the pricing rationale.";

# %%
const string QuoteAgentName = "Quote-Agent";
const string QuoteAgentInstructions = @"You are a assistant that create a quote for furniture purchase.
        1. Create a well-structured quote document that includes:
        2. A title page with the document title, date, and client name
        3. An introduction summarizing the purpose of the document
        4. A summary section with total estimated costs and recommendations
        5. Use clear headings, bullet points, and tables for easy readability
        6. All quotes are presented in markdown form";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
imageBytes
# Out:
# <div class="dni-plaintext"><pre>[ 137, 80, 78, 71, 13, 10, 26, 10, 0, 0, 0, 13, 73, 72, 68, 82, 0, 0, 3, 142 ... (823194 more) ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
AIAgent salesagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:SalesAgentName,instructions:SalesAgentInstructions);
AIAgent priceagent  = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:PriceAgentName,instructions:PriceAgentInstructions);
AIAgent quoteagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:QuoteAgentName,instructions:QuoteAgentInstructions);

# %%
var workflow = new WorkflowBuilder(salesagent)
            .AddEdge(salesagent,priceagent)
            .AddEdge(priceagent, quoteagent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new DataContent(imageBytes, "image/png"),new TextContent("Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture.Finally Output generates a quotation") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# ### Furniture Elements in the Image:
# 1. **TV Stand/Media Unit**
#    - A modern, low-profile media console with storage compartments and a light wood finish.
#    Suggested Purchase: IKEA Hemnes TV Unit, $250
#
# 2. **Sofa**
#    - A clean-lined, white fabric sofa with decorative cushions (blue and white).
#    Suggested Purchase: Wayfair Linen Upholstered Sofa, $450
#
# 3. **Accent Chair**
#    - Navy blue armchair with a unique contemporary design.
#    Suggested Purchase: West Elm Navy Velvet Chair, $350
#
# 4. **Coffee Table**
#    - Round aesthetic table with a combination of wood and marble-like finish.
#    Suggested Purchase: Article Luna Coffee Table, $200
#
# 5. **Side Table**
#    - Small glass-top table with a slender metal frame.
#    Suggested Purchase: CB2 Metal Side Table, $150
#
# 6. **Pendant Light (Left Corner)**
#    - Sleek spherical pendant light for lighting accents.
#    Suggested Purchase: Wayfair Globe Pendant Light Fixture, $100
#
# 7. **Chandelier**
#    - Mid-century modern chandelier with multiple globe bulbs.
#    Suggested Purchase: Lumens Modern Sputnik Chandelier, $300
#
# 8. **Floor Lamp**
#    - Minimal tripod-style floor lamp located on the left side.
#    Suggested Purchase: Target Tripod Floor Lamp, $75
#
# 9. **Curtains**
#    - Combination of sheer white and gray blackout curtains.
#    Suggested Purchase: Overstock Curtain Set, $200
#
# 10. **Wall Art**
#     - Deer-themed framed artwork on the wall.
#     Suggested Purchase: Wayfair Animal Print Wall Art, $50
#
# ---
#
# ### Quotation:
#
# | **Furniture Item**           | **Price ($)** |
# |-----------------------------|---------------|
# | TV Stand/Media Unit          | $250          |
# | Sofa                         | $450          |
# | Accent Chair                 | $350          |
# | Coffee Table                 | $200          |
# | Side Table                   | $150          |
# | Pendant Light                | $100          |
# | Chandelier                   | $300          |
# | Floor Lamp                   | $75           |
# | Curtains                     | $200          |
# | Wall Art                     | $50           |
#
# **Total Price:** **$2,125**
#
# Let me know if you’d like alternate product suggestions or additional details! 😊### Living Room Set Pricing Analysis and Budget Planning
#
# #### **Breakdown of Furniture Prices (General Pricing Ranges)**
# 1. **TV Stand/Media Unit**
#    - **Budget:** $100-$200 (Particleboard options like IKEA Besta series)
#    - **Mid-Range:** $250-$500 (Solid wood or veneer finishes like West Elm or Article)
#    - **Premium:** $600-$1,200 (Designer brands such as Crate & Barrel or Pottery Barn)
#    **Recommendation:** Mid-range options provide balance between affordability and durability. Estimated cost: **$300**
#
# 2. **Sofa**
#    - **Budget:** $300-$500 (Affordable upholstered sofas from Wayfair or IKEA)
#    - **Mid-Range:** $600-$1,200 (Performance fabric or tufted designs from Article, Joybird)
#    - **Premium:** $1,500-$3,000+ (Luxury brands like Restoration Hardware with premium materials)
#    **Recommendation:** Mid-range sofas for quality without overspending. Estimated cost: **$800**
#
# 3. **Accent Chair**
#    - **Budget:** $150-$300 (Simple designs from Target or Ashley Furniture)
#    - **Mid-Range:** $400-$700 (Stylish pieces from CB2 or West Elm)
#    - **Premium:** $800-$1,500 (High-end designer chairs from Design Within Reach)
#    **Recommendation:** Budget-friendly designs with aesthetic flair. Estimated cost: **$300**
#
# 4. **Coffee Table**
#    - **Budget:** $80-$150 (Basic wood/metal designs from IKEA or Walmart)
#    - **Mid-Range:** $200-$600 (Trendy styles with durable finishes from Article or Crate & Barrel)
#    - **Premium:** $800-$1,500+ (Designer options like marble imported tables)
#    **Recommendation:** Opt for mid-range options for style and usability. Estimated cost: **$250**
#
# 5. **Side Table**
#    - **Budget:** $50-$100 (Simple nightstand-style tables from Wayfair or Amazon)
#    - **Mid-Range:** $150-$300 (More finished designs with glass or wood details from CB2)
#    - **Premium:** $500+ (Custom furniture or designer pieces from luxury retailers)
#    **Recommendation:** Stick to mid-range or budget options. Estimated cost: **$100**
#
# 6. **Pendant Light**
#    - **Budget:** $50-$120 (Affordable pendant fixtures from Home Depot or IKEA)
#    - **Mid-Range:** $150-$400 (Chic designs from Wayfair or Lumens)
#    - **Premium:** $500-$1,000 (Designer brands like Visual Comfort or Artemide)
#    **Recommendation:** Mid-range designs offer uniqueness. Estimated cost: **$200**
#
# 7. **Chandelier**
#    - **Budget:** $100-$250 (Simple chandeliers from Home Depot or Amazon)
#    - **Mid-Range:** $300-$700 (Stylish pieces from Wayfair or CB2)
#    - **Premium:** $800-$1,500+ (Luxury pieces from Restoration Hardware or Lumens)
#    **Recommendation:** Choose a mid-range model for modern appeal. Estimated cost: **$350**
#
# 8. **Floor Lamp**
#    - **Budget:** $60-$100 (Affordable designs from Target or IKEA)
#    - **Mid-Range:** $150-$300 (More style-driven options from Wayfair or West Elm)
#    - **Premium:** $400+ (Designer or custom pieces from specialty stores)
#    **Recommendation:** Stick to budget-friendly options. Estimated cost: **$100**
#
# 9. **Curtains**
#    - **Budget:** $50-$150 (Polyester or cotton curtains from Walmart or Amazon)
#    - **Mid-Range:** $200-$400 (Linen blends or blackout styles from Pottery Barn or West Elm)
#    - **Premium:** $500-$1,000+ (Custom drapery with high-end fabrics)
#    **Recommendation:** Mid-range blackout curtains for function and quality. Estimated cost: **$200**
#
# 10. **Wall Art**
#     - **Budget:** $20-$75 (Prints and framed art from Amazon or IKEA)
#     - **Mid-Range:** $100-$300 (Canvas prints or custom pieces from Wayfair or Etsy)
#     - **Premium:** $500+ (Gallery-quality prints or originals)
#     **Recommendation:** Budget-friendly framed prints for simple decor. Estimated cost: **$75**
#
# ---
#
# ### **Estimated Total Cost for the Room Setup**
# - **Budget Range Total:** Approx. **$1,500-$2,500**
# - **Mid-Range Total:** Approx. **$3,000-$4,500**
# - **Premium Range Total:** Approx. **$5,500-$10,000+**
#
# ### **Final Recommendation (Mid-Range Focus)**
# - **Total Estimated Cost:** **$3,675**
#
# ---
#
# ### **Additional Costs to Consider**
# 1. **Delivery Fees:** $100-$300 depending on retailer and location (many offer free delivery on large purchases).
# 2. **Assembly Services:** $50-$200 depending on complexity of required furniture assembly.
# 3. **Accessories:** Throws, pillows, extra wall decor add approx. $200-$400 to total costs.
#
# ---
#
# ### **Seasonal Pricing Insights**
# - **Best Times to Buy:**
#    - **Black Friday and Cyber Monday (November):** Largest annual discounts on furniture across major brands.
#    - **End-of-Summer Sales (August):** Clearance for seasonal furniture pieces.
#    - **January:** After-Christmas clearance sales for home decor.
#
# ---
#
# ### **Shopping Recommendations**
# - **Budget Options:** IKEA, Walmart, Target, Amazon.
# - **Mid-Range Stores:** Article, West Elm, Wayfair, CB2.
# - **Premium Retailers:** Crate & Barrel, Restoration Hardware, Design Within Reach.
#
# Would you like alternative suggestions or help tailoring this setup? Let me know! 😊# **Furniture Purchase Quote**
#
# ### Prepared for:
# **[Client Name]**
# **Date:** [Insert Date]
#
# ---
#
# # **Introduction**
# This document provides a detailed quotation for furniture purchases tailored to [Client Name]'s requirements. The purpose is to help design a functional and aesthetically pleasing living room setup, showcasing mid-range and budget-friendly furniture options. The final quote includes an overall cost estimate and recommendations based on quality, affordability, and style.
#
# ---
#
# ## **Summary of Estimated Costs**
#
# | **Item**              | **Estimated Cost ($)** | **Category**   | **Recommendation**                  |
# |-----------------------|------------------------|----------------|-------------------------------------|
# | TV Stand              | $300                  | Mid-Range      | Durable and stylish finish.        |
# | Sofa                  | $800                  | Mid-Range      | Comfortable and long-lasting.       |
# | Accent Chair          | $300                  | Budget         | Affordable with aesthetic appeal.  |
# | Coffee Table          | $250                  | Mid-Range      | Functional and trendy design.       |
# | Side Table            | $100                  | Budget/Mid-Range | Simple and functional.             |
# | Pendant Light         | $200                  | Mid-Range      | Chic and modern design.             |
# | Chandelier            | $350                  | Mid-Range      | Elegant fixture for main lighting. |
# | Floor Lamp            | $100                  | Budget         | Affordable option.                  |
# | Curtains              | $200                  | Mid-Range      | High-quality blackout curtains.     |
# | Wall Art              | $75                   | Budget         | Framed prints for simple decor.     |
#
# | **Subtotal:**         | **$2,675**            |                |                                     |
# | **Additional Costs:** |                       |                |                                     |
# | Delivery Fees          | $150                 |                | Estimated fee—varies by retailer.   |
# | Assembly Services      | $100                 |                | Optional depending on needs.        |
# | Accessories            | $200                 |                | Extra decor (pillows, throws, etc.).|
#
# | **Grand Total**        | **$3,125**            |                |                                     |
#
# ---
#
# # **Recommendations**
# Based on your budget and needs:
# - **Furniture Selection:** Opt for mid-range furniture with a balance of affordability, quality, and style.
# - **Overall Budget Flexibility:** Maintain flexibility for delivery fees, decorative accessories, and possible seasonal discounts to lower costs further.
# - **Sales Consideration:** Plan purchases during sales events like **Black Friday**, **January clearances**, or **end-of-summer offers** to maximize value.
#
# ---
#
# ## **Detailed Breakdown**
#
# ### **Living Room Furniture Options**
#
# | **Furniture Item** | **Store Recommendation** | **Reason for Choice**                                   |
# |---------------------|--------------------------|--------------------------------------------------------|
# | TV Stand           | Article, West Elm        | Design focus, durable finishes.                        |
# | Sofa               | Joybird, Wayfair         | Comfort, durability, optimal price point.              |
# | Accent Chair       | Target, Ashley Furniture | Affordable designs, modern chic.                      |
# | Coffee Table       | Article, Crate & Barrel  | Functional design with mid-range aesthetic appeal.     |
# | Side Table         | Wayfair, CB2             | Stylish small budget options available.                |
# | Pendant Light      | West Elm, Lumens         | Modern, elegant mid-range options.                    |
# | Chandelier         | Wayfair, CB2             | Affordable and high-impact for lighting centerpiece.   |
# | Floor Lamp         | Target, IKEA             | Simple design with budget practicality.                |
# | Curtains           | IKEA, West Elm           | Blackout and linen options blend quality with style.   |
# | Wall Art           | Etsy, Amazon             | Affordable framed prints and unique decorative pieces.|
#
# ---
#
# # **Next Steps**
# - Confirm your preferred style (materials, finishes, and color schemes).
# - Specify delivery preferences and if assembly services are required.
# - Discuss accessories and additional decor (optional).
#
# Please feel free to contact us if you’d like to adjust your quote or explore more options. We are here to help fine-tune your living room setup and provide you with a seamless shopping experience.
#
# Thank you!
#
# **[Your Company Name]**
