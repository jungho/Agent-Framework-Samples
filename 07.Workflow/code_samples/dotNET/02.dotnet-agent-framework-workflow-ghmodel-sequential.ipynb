# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: System.ClientModel, 1.6.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.Workflows\bin\Debug\net9.0\Microsoft.Agents.Workflows.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;
using OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id =  "gpt-4o";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

var imgPath ="../imgs/home.png";

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
const string SalesAgentName = "Sales-Agent";
const string SalesAgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
const string PriceAgentName = "Price-Agent";
const string PriceAgentInstructions = @"You are a furniture pricing specialist and budget consultant. Your responsibilities include:
        1. Analyze furniture items and provide realistic price ranges based on quality, brand, and market standards
        2. Break down pricing by individual furniture pieces
        3. Provide budget-friendly alternatives and premium options
        4. Consider different price tiers (budget, mid-range, premium)
        5. Include estimated total costs for room setups
        6. Suggest where to find the best deals and shopping recommendations
        7. Factor in additional costs like delivery, assembly, and accessories
        8. Provide seasonal pricing insights and best times to buy
        Always format your response with clear price breakdowns and explanations for the pricing rationale.";

# %%
const string QuoteAgentName = "Quote-Agent";
const string QuoteAgentInstructions = @"You are a assistant that create a quote for furniture purchase.
        1. Create a well-structured quote document that includes:
        2. A title page with the document title, date, and client name
        3. An introduction summarizing the purpose of the document
        4. A summary section with total estimated costs and recommendations
        5. Use clear headings, bullet points, and tables for easy readability
        6. All quotes are presented in markdown form";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
imageBytes
# Out:
# <div class="dni-plaintext"><pre>[ 137, 80, 78, 71, 13, 10, 26, 10, 0, 0, 0, 13, 73, 72, 68, 82, 0, 0, 3, 142 ... (823194 more) ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
AIAgent salesagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:SalesAgentName,instructions:SalesAgentInstructions);
AIAgent priceagent  = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:PriceAgentName,instructions:PriceAgentInstructions);
AIAgent quoteagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:QuoteAgentName,instructions:QuoteAgentInstructions);

# %%
var workflow = new WorkflowBuilder(salesagent)
            .AddEdge(salesagent,priceagent)
            .AddEdge(priceagent, quoteagent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new DataContent(imageBytes, "image/png"),new TextContent("Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture.Finally Output generates a quotation") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# ### Furniture Identified:
# 1. **TV Stand/Entertainment Unit**
#    - Modern wooden TV stand with drawers.
#    - Estimated price: $350 - $500
#
# 2. **Sectional Sofa**
#    - White fabric sectional sofa with blue and gray accent pillows.
#    - Estimated price: $700 - $1,200
#
# 3. **Single Accent Chair**
#    - Navy-blue, high-back modern accent chair.
#    - Estimated price: $300 - $450
#
# 4. **Coffee Table**
#    - Oval modern coffee table with stone or marble-like top.
#    - Estimated price: $250 - $400
#
# 5. **Side Table (Next to Accent Chair)**
#    - Minimalist round side table with white top and metal legs.
#    - Estimated price: $150 - $250
#
# 6. **Lighting Fixture (Ceiling)**
#    - Modern black spider chandelier with glass globe shades.
#    - Estimated price: $200 - $350
#
# 7. **Floor Lamp**
#    - Minimalist floor lamp with a silver stand and globe light bulbs.
#    - Estimated price: $150 - $200
#
# 8. **Decorative Elements**
#    - Artwork above the sofa (Deer design): $80 - $150
#    - Table decor (vases, sculptures): $70 - $120
#
# ---
#
# ### Quotation:
#
# | **Item**            | **Quantity** | **Estimated Price**  |
# |---------------------|-------------|----------------------|
# | TV Stand            | 1           | $350 - $500         |
# | Sectional Sofa      | 1           | $700 - $1,200       |
# | Accent Chair        | 1           | $300 - $450         |
# | Coffee Table        | 1           | $250 - $400         |
# | Side Table          | 1           | $150 - $250         |
# | Ceiling Fixture     | 1           | $200 - $350         |
# | Floor Lamp          | 1           | $150 - $200         |
# | Artwork             | 1           | $80 - $150          |
# | Table Decorations   | 1 set       | $70 - $120          |
#
# ---
#
# ### **Total Estimated Cost:**
# **$2,250 - $3,620**
#
# (Note: Final pricing may depend on specific brands, materials, and retailer prices in your region.)### **Room Furniture Breakdown with Pricing Options**
#
# Here is the pricing analysis for a living room setup based on the items you’ve listed, including price tiers (budget, mid-range, premium) and additional cost considerations.
#
# ---
#
# ### **Furniture Pricing Breakdown**
#
# #### 1. **TV Stand/Entertainment Unit**
# - **Budget:** $150 - $250 (e.g., MDF material, minimal design, found at IKEA or Amazon Basics)
# - **Mid-Range:** $350 - $500 (e.g., solid wood or engineered wood with drawers; from brands like Wayfair or Ashley Furniture)
# - **Premium:** $800 - $1,200 (crafted hardwood, custom finishes, integrated cable management; from brands like West Elm or Pottery Barn)
#
# ---
#
# #### 2. **Sectional Sofa**
# - **Budget:** $500 - $750 (fabric, foam cushions, limited customization; Walmart or Overstock)
# - **Mid-Range:** $1,000 - $1,500 (more durable materials, better support, variety of colors; Joybird or CB2)
# - **Premium:** $2,000 - $4,500+ (premium linen or leather, deep seating, modular designs; Restoration Hardware or Design Within Reach)
#
# ---
#
# #### 3. **Accent Chair**
# - **Budget:** $180 - $250 (standard foam cushioning, simple fabrics; Target or Wayfair)
# - **Mid-Range:** $300 - $450 (designer fabric, ergonomic features; Crate & Barrel or Article)
# - **Premium:** $750 - $1,000+ (velvet or leather upholstery, custom designs; brands like Anthropologie or West Elm)
#
# ---
#
# #### 4. **Coffee Table**
# - **Budget:** $120 - $200 (simple MDF or glass-top designs; available on Overstock or IKEA)
# - **Mid-Range:** $250 - $400 (marble-look laminate, solid wood, or metal bases; CB2 or West Elm)
# - **Premium:** $800 - $1,500+ (real marble tops, intricate bases; Pottery Barn or specialty designers like Crate & Barrel)
#
# ---
#
# #### 5. **Side Table**
# - **Budget:** $80 - $120 (basic designs with thin metal legs and tabletop; Amazon or Walmart)
# - **Mid-Range:** $150 - $250 (unique materials like faux marble, better craftsmanship; Wayfair or CB2)
# - **Premium:** $350 - $700 (designer items with solid wood, stone, or marble detailing; high-end boutiques)
#
# ---
#
# #### 6. **Lighting Fixture (Chandelier/Spider Light)**
# - **Budget:** $120 - $200 (simple spider light with non-dimmable features; Amazon or Wayfair)
# - **Mid-Range:** $300 - $500 (modern aesthetic features, dimmable lighting; AllModern or Article)
# - **Premium:** $700 - $1,200+ (hand-finished hardware, custom glass shades; Restoration Hardware or specialty lighting stores)
#
# ---
#
# #### 7. **Floor Lamp**
# - **Budget:** $70 - $120 (simple stand-up lamps with standard bulbs; Walmart or IKEA)
# - **Mid-Range:** $150 - $200 (sleek design with LED bulbs; Article or Pottery Barn)
# - **Premium:** $400 - $800+ (artisan-crafted floor lamps with unique designs; premium lighting boutiques)
#
# ---
#
# #### 8. **Wall Artwork (Deer Painting/Abstract)**
# - **Budget:** $50 - $100 (printed versions or framed reproductions; Amazon or Target)
# - **Mid-Range:** $150 - $250 (canvas prints or hand-painted options; Society6 or West Elm)
# - **Premium:** $500 - $1,500+ (original artwork or limited-edition signed prints; independent artists or gallery purchases)
#
# ---
#
# #### 9. **Tabletop Decorations (Vases/Accessories)**
# - **Budget:** $50 - $80 (basic ceramic or glass vases; IKEA or Target)
# - **Mid-Range:** $100 - $200 (designer vases with unique finishes; CB2 or Anthropologie)
# - **Premium:** $300 - $500+ (handcrafted artisanal décor; high-end home stores or custom orders)
#
# ---
#
# ### **Estimated Total Living Room Costs by Tier**
# Here’s how the cost ranges stack up for the entire room based on tiers:
#
# | **Tier**      | **Estimated Total Costs**         | **Details**                                                                                  |
# |---------------|----------------------------------|--------------------------------------------------------------------------------------------|
# | **Budget**   | **$1,370 - $2,070**              | Affordable functional pieces for smaller spaces or tighter budgets                          |
# | **Mid-Range** | **$3,100 - $4,700**              | Well-built furniture with modern aesthetics and more durable materials                      |
# | **Premium**   | **$6,300 - $10,300+**            | High-end designs, customizations, and premium quality finishes from boutique brands         |
#
# ---
#
# ### **Budget-Friendly Alternatives**
# If you’re budget-conscious, here are some cost-saving suggestions:
# 1. **TV Stand & Sofa**: Explore IKEA, Target, or Overstock for TV stands and sofas under $800.
# 2. **Chandelier & Floor Lamps**: Look at Lowe’s or Home Depot for stylish yet affordable lighting options.
# 3. **Accent Chair & Décor**: Search Amazon Basics or Hobby Lobby for reasonably priced accent chairs and artwork.
# 4. **Seasonal Sales:** Consider buying during holiday sales like Black Friday, end-of-summer clearance, or Presidents' Day for significant discounts.
#
# ---
#
# ### **Premium Upgrades**
# If splurging is an option:
# 1. **Sectional Sofa**: Restoration Hardware’s Cloud Sofa ($3,500+) for ultimate comfort and style.
# 2. **Chandelier**: Handcrafted chandeliers from Design Within Reach ($900–$1,400).
# 3. **Coffee Table**: Real stone coffee table at Crate & Barrel or West Elm ($1,000+).
#
# ---
#
# ### **Additional Costs to Keep in Mind**
# 1. **Delivery Fees**: Typically $50–$200 depending on retailer and distance.
# 2. **Assembly Costs**: $50–$150 per item, though some retailers (e.g., Wayfair) offer assembly services.
# 3. **Accessory Costs**: Throw pillows, rugs, or storage bins may add another $300–$500 depending on style and quality.
#
# ---
#
# ### **Seasonal Pricing Insights**
#
# - **Best Times to Buy**:
#   - **January & February** (post-holiday sales)
#   - **May** (Memorial Day sales)
#   - **November** (Black Friday or Cyber Monday)
#
# - **Off-Season Discounts**: Clearance pricing often occurs in July/August when new inventory arrives.
#
# ---
#
# ### **Shopping Recommendations**
# 1. **Budget Brands**: Walmart, IKEA, Amazon, Overstock.
# 2. **Mid-Range Brands**: West Elm, Article, Joybird, Wayfair.
# 3. **Premium Brands**: Restoration Hardware, Design Within Reach, Pottery Barn.
#
# Let me know which price tier aligns with your goals, and I can refine the suggestions further!## **Furniture Purchase Quote**
#
# **Prepared for:** [Client Name]
# **Date:** [Insert Date]
# **Prepared by:** [Your Name or Company Name]
#
# ---
#
# ### **Introduction**
#
# This document serves as a detailed quote for purchasing furniture for your living room. It provides pricing options by tier—budget, mid-range, and premium—to accommodate your unique requirements and budget. Each section includes recommendations to help you make an informed decision, ensuring both functionality and style for your space.
#
# ---
#
# ### **Summary of Total Costs**
#
# | **Tier**        | **Estimated Total Costs**     | **Details**                                      |
# |------------------|-------------------------------|-------------------------------------------------|
# | **Budget**       | **$1,370 - $2,070**          | Cost-effective options for functional furniture |
# | **Mid-Range**    | **$3,100 - $4,700**          | Balanced quality and style                      |
# | **Premium**      | **$6,300 - $10,300+**        | Luxury materials and design                     |
#
# #### **Recommendations**:
# - **If Budget-Conscious**: Select items from IKEA, Overstock, Amazon Basics.
# - **If Seeking Mid-Range Quality**: Prioritize West Elm and Wayfair products for a mix of durability and style.
# - **If Opting for Premium**: Invest in Restoration Hardware or Design Within Reach for bespoke, high-end furniture.
#
# ---
#
# ### **Furniture Pricing Breakdown**
#
# #### **1. TV Stand/Entertainment Unit**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $150 - $250    | MDF material, minimal design                    |
# | **Mid-Range**    | $350 - $500    | Solid wood, practical storage                   |
# | **Premium**      | $800 - $1,200  | Hardwood, custom finishes, integrated features  |
#
# ---
#
# #### **2. Sectional Sofa**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $500 - $750    | Basic foam cushions, fabric upholstery          |
# | **Mid-Range**    | $1,000 - $1,500| Durable materials, stylish designs             |
# | **Premium**      | $2,000 - $4,500| Premium leather or modular options             |
#
# ---
#
# #### **3. Accent Chair**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $180 - $250    | Foam cushioning, simple fabrics                |
# | **Mid-Range**    | $300 - $450    | Designer fabric, ergonomic features            |
# | **Premium**      | $750 - $1,000  | Velvet or leather upholstery                   |
#
# ---
#
# #### **4. Coffee Table**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $120 - $200    | Simple MDF or glass-top designs                |
# | **Mid-Range**    | $250 - $400    | Marble-look laminate or solid wood             |
# | **Premium**      | $800 - $1,500  | Real marble tops, intricate bases              |
#
# ---
#
# #### **5. Side Table**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $80 - $120     | Basic lightweight designs                      |
# | **Mid-Range**    | $150 - $250    | Designer options, durable craftsmanship        |
# | **Premium**      | $350 - $700    | Stone-top or custom wood detailing             |
#
# ---
#
# #### **6. Lighting Fixture (Chandelier/Spider Light)**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $120 - $200    | Simple designs without dimmer                  |
# | **Mid-Range**    | $300 - $500    | Modern aesthetics, dimmable features           |
# | **Premium**      | $700 - $1,200  | Hand-finished materials, artisanal quality     |
#
# ---
#
# #### **7. Floor Lamp**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $70 - $120     | Simple stand-up lamps                         |
# | **Mid-Range**    | $150 - $200    | Sleek design with LED bulbs                   |
# | **Premium**      | $400 - $800    | Artisan-crafted elegant designs               |
#
# ---
#
# #### **8. Wall Artwork**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $50 - $100     | Printed versions or framed reproductions       |
# | **Mid-Range**    | $150 - $250    | Unique canvas prints                          |
# | **Premium**      | $500 - $1,500  | Original or limited-edition pieces            |
#
# ---
#
# #### **9. Tabletop Decorations (Vases, Accessories)**
# | **Tier**        | **Price Range** | **Description**                                  |
# |------------------|----------------|-------------------------------------------------|
# | **Budget**       | $50 - $80      | Basic ceramic or glass vases                   |
# | **Mid-Range**    | $100 - $200    | Designer vases                                 |
# | **Premium**      | $300 - $500    | Handcrafted artisanal décor                   |
#
# ---
#
# ### **Additional Cost Considerations**
#
# 1. **Delivery Fee**: $50 - $200
# 2. **Assembly Services**: $50 - $150 per item (varies by retailer)
# 3. **Accessory Add-ons**: Rugs, throw pillows, seasonal décors may cost $300 - $500 additional.
#
# ---
#
# ### **Conclusion**
#
# Based on your preferences and budget, we recommend starting with mid-range options for optimal balance between quality and price. Seasonal sales and retailer discounts can help lower costs significantly. Let us know which tier matches your vision, and we can proceed with the order.
#
# Thank you for the opportunity to assist with your furniture needs!
#
# ---
# *(Prepared in Markdown for easy exporting to web, PDF, or document formats.)*
