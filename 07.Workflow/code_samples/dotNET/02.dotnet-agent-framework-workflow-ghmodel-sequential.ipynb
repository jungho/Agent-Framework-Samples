# %% [markdown]
# # ⏩ Sequential Agent Workflows with GitHub Models (.NET)
#
# ## 📋 Advanced Sequential Processing Tutorial
#
# This notebook demonstrates **sequential workflow patterns** using the Microsoft Agent Framework for .NET and GitHub Models. You'll learn how to build sophisticated, step-by-step processing pipelines where agents execute in a specific order, with each stage building upon the results of the previous stage.
#
# ## 🎯 Learning Objectives
#
# ### 🔄 **Sequential Processing Architecture**
# - **Linear Workflow Design**: Create step-by-step processing pipelines with clear dependencies
# - **State Management**: Maintain context and data flow across sequential workflow stages
# - **GitHub Models Integration**: Leverage GitHub's AI models in multi-stage .NET workflows
# - **Enterprise Pipeline Patterns**: Build production-ready sequential processing systems
#
# ### 🏗️ **Advanced Sequential Patterns**
# - **Stage-Gate Processing**: Implement validation checkpoints between workflow stages
# - **Context Preservation**: Maintain state and accumulated knowledge across all stages
# - **Error Propagation**: Handle failures gracefully in sequential processing chains
# - **Performance Optimization**: Efficient sequential execution with minimal overhead
#
# ### 🏢 **Enterprise Sequential Applications**
# - **Document Processing Pipeline**: Multi-stage document analysis, transformation, and validation
# - **Quality Assurance Workflows**: Sequential review, validation, and approval processes
# - **Content Production Pipeline**: Research → Writing → Editing → Review → Publishing
# - **Business Process Automation**: Multi-step business workflows with clear stage dependencies
#
# ## ⚙️ Prerequisites & Setup
#
# ### 📦 **Required NuGet Packages**
#
# Essential packages for .NET sequential workflows:
#
# ```xml
# <!-- Core AI Framework -->
# <PackageReference Include="Microsoft.Extensions.AI" Version="9.9.0" />
#
# <!-- Client Model Abstractions -->
# <PackageReference Include="System.ClientModel" Version="1.6.1.0" />
#
# <!-- Azure Identity and Async LINQ Support -->
# <PackageReference Include="Azure.Identity" Version="1.15.0" />
# <PackageReference Include="System.Linq.Async" Version="6.0.3" />
#
# <!-- Local Agent Framework References -->
# <!-- Microsoft.Agents.AI.dll - Core agent abstractions -->
# <!-- Microsoft.Agents.AI.OpenAI.dll - GitHub Models integration -->
# ```
#
# ### 🔑 **GitHub Models Configuration**
#
# **Environment Setup (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **Configuration Management:**
# ```csharp
# // Load environment variables securely
# Env.Load("../../../.env");
# var githubToken = Environment.GetEnvironmentVariable("GITHUB_TOKEN");
# var githubEndpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT");
# var modelId = Environment.GetEnvironmentVariable("GITHUB_MODEL_ID");
# ```
#
# ### 🏗️ **Sequential Workflow Architecture**
#
# ```mermaid
# graph TD
#     A[Initial Input] --> B[Stage 1: Analysis Agent]
#     B --> C[Checkpoint 1]
#     C --> D[Stage 2: Processing Agent]
#     D --> E[Checkpoint 2]
#     E --> F[Stage 3: Validation Agent]
#     F --> G[Final Output]
#
#     H[State Context] --> B
#     H --> D
#     H --> F
#
#     I[GitHub Models API] --> B
#     I --> D
#     I --> F
# ```
#
# **Key Components:**
# - **Sequential Agents**: Specialized agents for each processing stage
# - **State Context**: Maintains accumulated data and decisions across stages
# - **Checkpoints**: Validation points between stages to ensure quality and consistency
# - **GitHub Models Client**: Consistent AI model access across all workflow stages
#
# ## 🎨 **Sequential Workflow Design Patterns**
#
# ### 📝 **Document Processing Pipeline**
# ```
# Raw Document → Content Extraction → Analysis → Validation → Structured Output
# ```
#
# ### 🎯 **Content Creation Workflow**
# ```
# Brief/Requirements → Research → Content Creation → Review → Final Polish
# ```
#
# ### 🔍 **Quality Assurance Pipeline**
# ```
# Initial Review → Technical Validation → Compliance Check → Final Approval
# ```
#
# ### 💼 **Business Intelligence Workflow**
# ```
# Data Collection → Processing → Analysis → Report Generation → Distribution
# ```
#
# ## 🏢 **Enterprise Sequential Benefits**
#
# ### 🎯 **Reliability & Quality**
# - **Deterministic Processing**: Consistent, repeatable outcomes through structured stages
# - **Quality Gates**: Validation checkpoints ensure quality at each stage
# - **Error Isolation**: Problems in one stage don't propagate to subsequent stages
# - **Audit Trails**: Complete tracking of decisions and transformations at each stage
#
# ### 📈 **Scalability & Performance**
# - **Modular Design**: Each stage can be optimized independently
# - **Resource Management**: Efficient allocation of AI model resources across stages
# - **State Optimization**: Minimal state transfer between stages for optimal performance
# - **Parallel Stage Groups**: Multiple sequential workflows can run in parallel
#
# ### 🔒 **Security & Compliance**
# - **Stage-Level Security**: Different security policies for different processing stages
# - **Data Validation**: Ensure data integrity and compliance at each checkpoint
# - **Access Control**: Granular permissions for different workflow stages
# - **Regulatory Compliance**: Meet regulatory requirements through structured processing
#
# ### 📊 **Monitoring & Analytics**
# - **Stage-Level Metrics**: Performance monitoring for each workflow stage
# - **Bottleneck Identification**: Identify and optimize slow stages
# - **Quality Metrics**: Track quality and success rates at each stage
# - **Process Optimization**: Continuous improvement based on stage-level analytics
#
# Let's build robust sequential AI processing pipelines! 🚀

# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: System.ClientModel, 1.6.1.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>System.ClientModel, 1.6.1</span></li></ul></div></div>

# %%
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.Workflows\bin\Debug\net9.0\Microsoft.Agents.Workflows.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;
using OpenAI;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using Microsoft.Agents.Workflows;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id =  "gpt-4o";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

var imgPath ="../imgs/home.png";

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint = new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
const string SalesAgentName = "Sales-Agent";
const string SalesAgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
const string PriceAgentName = "Price-Agent";
const string PriceAgentInstructions = @"You are a furniture pricing specialist and budget consultant. Your responsibilities include:
        1. Analyze furniture items and provide realistic price ranges based on quality, brand, and market standards
        2. Break down pricing by individual furniture pieces
        3. Provide budget-friendly alternatives and premium options
        4. Consider different price tiers (budget, mid-range, premium)
        5. Include estimated total costs for room setups
        6. Suggest where to find the best deals and shopping recommendations
        7. Factor in additional costs like delivery, assembly, and accessories
        8. Provide seasonal pricing insights and best times to buy
        Always format your response with clear price breakdowns and explanations for the pricing rationale.";

# %%
const string QuoteAgentName = "Quote-Agent";
const string QuoteAgentInstructions = @"You are a assistant that create a quote for furniture purchase.
        1. Create a well-structured quote document that includes:
        2. A title page with the document title, date, and client name
        3. An introduction summarizing the purpose of the document
        4. A summary section with total estimated costs and recommendations
        5. Use clear headings, bullet points, and tables for easy readability
        6. All quotes are presented in markdown form";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
imageBytes
# Out:
# <div class="dni-plaintext"><pre>[ 137, 80, 78, 71, 13, 10, 26, 10, 0, 0, 0, 13, 73, 72, 68, 82, 0, 0, 3, 142 ... (823194 more) ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
AIAgent salesagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:SalesAgentName,instructions:SalesAgentInstructions);
AIAgent priceagent  = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:PriceAgentName,instructions:PriceAgentInstructions);
AIAgent quoteagent = openAIClient.GetChatClient(github_model_id).CreateAIAgent(
    name:QuoteAgentName,instructions:QuoteAgentInstructions);

# %%
var workflow = new WorkflowBuilder(salesagent)
            .AddEdge(salesagent,priceagent)
            .AddEdge(priceagent, quoteagent)
            .Build();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new DataContent(imageBytes, "image/png"),new TextContent("Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture.Finally Output generates a quotation") 
]);

# %%
StreamingRun run = await InProcessExecution.StreamAsync(workflow, userMessage);

# %%
await run.TrySendMessageAsync(new TurnToken(emitEvents: true));
string id="";
string messageData="";
await foreach (WorkflowEvent evt in run.WatchStreamAsync().ConfigureAwait(false))
{
    if (evt is AgentRunUpdateEvent executorComplete)
    {
        if(id=="")
        {
            id=executorComplete.ExecutorId;
        }
        if(id==executorComplete.ExecutorId)
        {
            messageData+=executorComplete.Data.ToString();
        }
        else
        {
            id=executorComplete.ExecutorId;
        }
        // Console.WriteLine($"{executorComplete.ExecutorId}: {executorComplete.Data}");
    }
}

Console.WriteLine(messageData);
# Out:
# Based on the image provided, I have identified the key furniture pieces and estimated an average cost range based on standard market pricing for items of similar design. Here's the breakdown of the furniture elements:
#
# ### Furniture List & Costs:
# 1. **Modern White Fabric Sofa (3-Seater)**
#    - Description: A minimalist white fabric sofa accommodating three people. Comes with accent pillows in blue and white.
#    - Estimated Price: $800
#
# 2. **Round Coffee Table**
#    - Description: A sleek round table with a white top and light wooden legs.
#    - Estimated Price: $200
#
# 3. **TV Console/Entertainment Unit**
#    - Description: Light wood unit with shelves and drawers, spacious enough for a large TV and decor.
#    - Estimated Price: $400
#
# 4. **Accent Chair**
#    - Description: Deep navy-blue modern accent chair for additional seating.
#    - Estimated Price: $350
#
# 5. **Modern Chandelier Light Fixture**
#    - Description: Black geometric chandelier with globe lamps.
#    - Estimated Price: $150
#
# 6. **Side Table (Near Accent Chair)**
#    - Description: Small light wood round side table with metal legs.
#    - Estimated Price: $120
#
# 7. **Side Table (Near Sofa)**
#    - Description: Cream rectangular side table with a black frame.
#    - Estimated Price: $100
#
# 8. **Table Lamp (On Sofa-Side Table)**
#    - Description: Compact table lamp for soft lighting.
#    - Estimated Price: $80
#
# 9. **Curtains**
#    - Description: Layered translucent white curtains with dark solid blackout panels.
#    - Estimated Price: $150
#
# 10. **Framed Wall Art**
#     - Description: Large framed artwork above the sofa (deer illustration depicted).
#     - Estimated Price: $75
#
# ### Total Estimated Quotation:
# | **Item**                        | **Price** |
# |---------------------------------|-----------|
# | White Fabric Sofa               | $800      |
# | Round Coffee Table              | $200      |
# | TV Console                      | $400      |
# | Accent Chair                    | $350      |
# | Chandelier Light Fixture        | $150      |
# | Side Table (Near Accent Chair)  | $120      |
# | Side Table (Near Sofa)          | $100      |
# | Table Lamp                      | $80       |
# | Curtains                        | $150      |
# | Framed Wall Art                 | $75       |
# | **Total**                       | **$2,425** |
#
# #### Notes:
# - The prices provided are average market estimates and may vary based on brand, material quality, and retailer. These prices should be confirmed with your chosen supplier for accuracy.
# - Adding a rug or some greenery (indoor plants) could further enhance the room's aesthetic if needed. Let me know if you'd like recommendations for additional decor!
#
# To provide a comprehensive response, let’s dive into a detailed analysis of the furniture and its pricing, with options spanning budget, mid-range, and premium tiers. I’ll also provide alternatives, delivery/assembly cost insights, seasonal advice, and total room setup costs.
#
# ---
#
# ### **Price Breakdown by Furniture Pieces**
#
# #### **1. Modern White Fabric Sofa (3-Seater)**
#    - **Budget Option**: $300–$500 (polyester or microfiber fabric, generic brands; available at IKEA or Wayfair)
#    - **Mid-Range Option**: $800–$1,200 (higher-density foam and stain-resistant fabric; available at Article or West Elm)
#    - **Premium Option**: $2,000–$3,500 (performance fabric, kiln-dried hardwood frame; brands like Pottery Barn or Joybird)
#
# #### **2. Round Coffee Table**
#    - **Budget Option**: $75–$150 (MDF tops, minimal wood or metal base; Target, Walmart)
#    - **Mid-Range Option**: $200–$400 (solid wood, ceramic, or glass tops; Crate & Barrel, AllModern)
#    - **Premium Option**: $600+ (designer pieces, marble tops, mixed materials; Restoration Hardware, CB2)
#
# #### **3. TV Console/Entertainment Unit**
#    - **Budget Option**: $150–$300 (particleboard or laminate; IKEA, Amazon)
#    - **Mid-Range Option**: $400–$600 (solid wood with veneer or engineered wood; West Elm, Raymour & Flanigan)
#    - **Premium Option**: $1,200+ (custom millwork, premium finishes; Room & Board, high-end furniture stores)
#
# #### **4. Accent Chair**
#    - **Budget Option**: $100–$250 (basic polyester fabric; Wayfair, Home Depot)
#    - **Mid-Range Option**: $350–$600 (upholstered seating, contemporary or mid-century modern; Article, West Elm)
#    - **Premium Option**: $1,000+ (custom-crafted, leather or designer fabric; Herman Miller, Design Within Reach)
#
# #### **5. Modern Chandelier/Light Fixture**
#    - **Budget Option**: $75–$120 (simple geometric chandeliers; Wayfair, Home Depot)
#    - **Mid-Range Option**: $150–$300 (designer-inspired fixtures with thoughtful details; AllModern, CB2)
#    - **Premium Option**: $500–$1,200 (luxury designs, handcrafted metalwork; Circa Lighting, RH)
#
# #### **6. Side Tables (Near Accent Chair & Near Sofa)**
#    - **Budget Option**: $50–$100 each (minimalist designs in MDF or veneer; IKEA, Amazon)
#    - **Mid-Range Option**: $120–$250 each (solid wood or mixed materials; AllModern, West Elm)
#    - **Premium Option**: $400+ each (luxury designs, artisanal builds; CB2, Pottery Barn)
#
# #### **7. Table Lamp**
#    - **Budget Option**: $30–$60 (basic design, plastic/metal material; Walmart, Target)
#    - **Mid-Range Option**: $80–$150 (ceramic, glass details; West Elm, Anthropologie)
#    - **Premium Option**: $300+ (designer labels, integrated smart technology; RH, Mitzi Lighting)
#
# #### **8. Curtains**
#    - **Budget Option**: $50–$100 (synthetic blackout panels; Target, Amazon)
#    - **Mid-Range Option**: $150–$300 (linen/cotton blends, layered style; Pottery Barn, The Shade Store)
#    - **Premium Option**: $500+ (custom-sized drapes, high-end textiles; Calico Corners, bespoke services)
#
# #### **9. Wall Art (Framed)**
#    - **Budget Option**: $20–$50 (poster prints in budget frames; Target, HomeGoods)
#    - **Mid-Range Option**: $75–$200 (canvas or high-quality prints with artistic touches; Society6, Minted)
#    - **Premium Option**: $300+ (original artwork or limited-edition prints; local galleries, Saatchi Art)
#
# ---
#
# ### **Estimated Total Cost for Room Setup**
#
# | **Price Tier**     | **Furniture Cost** | **Delivery & Assembly** | **Accessories** | **Estimated Total** |
# |--------------------|--------------------|-------------------------|-----------------|---------------------|
# | Budget ($)         | $1,100–$1,500     | $100–$200              | $100–$200       | $1,300–$1,900       |
# | Mid-Range ($$)     | $2,400–$3,300     | $200–$400              | $200–$400       | $2,800–$4,100       |
# | Premium ($$$)      | $7,000+           | $500+                  | $500+           | $8,000+             |
#
# ---
#
# ### **Where to Find the Best Deals**
#
# 1. **Budget Stores**: IKEA, Wayfair, Walmart, Overstock, Target
#    - Great for affordable, durable pieces for renters or first-time furnishing.
#
# 2. **Mid-Range Stores**: West Elm, Article, AllModern, CB2
#    - Ideal for balancing quality with style and pricing.
#
# 3. **Premium Stores**: Pottery Barn, Room & Board, RH (Restoration Hardware), Design Within Reach
#    - Perfect if you're looking for artisan craftsmanship or luxury furnishings.
#
# 4. **Outlets & Flash Sales**: West Elm Outlet, Pottery Barn Outlet, Overstock, Wayfair’s seasonal sales can offer high-end items at discounted rates.
#
# ---
#
# ### **Seasonal Insights & Best Times to Buy**
#
# 1. **Winter (Post-Holiday Sales)**: Major discounts on furniture during January clearance events.
# 2. **Spring (Memorial Day)**: Pre-summer sales on outdoor and indoor furniture alike.
# 3. **Summer (4th of July & Labor Day)**: Large sales events catering to new collections arriving after summer.
# 4. **Fall (End-of-Season Clearance)**: Best time to purchase floor models or previous-year collections.
#
# **Pro Tip**: Sign up for newsletters from stores to get first access to seasonal sales and check furniture outlet pricing.
#
# ---
#
# ### **Additional Costs to Factor In**
#
# 1. **Delivery Fees**:
#    - Budget Shipping (Curbside): $50–$100.
#    - White Glove (In-Room Setup): $150–$400.
#
# 2. **Assembly Costs**:
#    - Self-Assembly: $0 if you DIY (often required with IKEA and some online brands).
#    - Professional Assembly: $50–$200 per piece (services like TaskRabbit).
#
# 3. **Accessories**:
#    - Textiles (throw blankets, pillows): $100–$300.
#    - Rugs: $150–$700 depending on size and material.
#    - Greenery (plants, planters): $50–$200.
#
# ---
#
# ### **Budget-Friendly Room Setup Example**
#
# For a stylish yet affordable room (budget tier):
# - Sofa: $400 (IKEA Kivik 3-seater)
# - Coffee Table: $80 (Target)
# - TV Console: $150 (Wayfair)
# - Accent Chair: $200 (HomeGoods)
# - Area Rug: $150 (Amazon)
# - Side Tables (2): $100 (IKEA Lack series)
# - Curtains: $60 (Walmart)
# - Framed Art: $40 (Target)
# - Delivery + Assembly: $150
# **Total Cost**: $1,330
#
# ---
#
# Let me know if I can customize these suggestions further to match your style or space needs!# **Furniture Purchase Quote**
# **Date:** [Insert Date]
# **Client Name:** [Insert Client Name]
#
# ---
#
# # **Introduction**
# This document provides a formal quote for the furniture and decor required to set up a living room space. It estimates the total costs of all required items, presents options across budget, mid-range, and premium tiers, and includes recommendations on where to find the best deals. Delivery and assembly costs have also been calculated based on selected tiers and preferences.
#
# ---
#
# # **Summary of Total Estimated Costs & Recommendations**
#
# | **Price Tier**     | **Furniture Cost** | **Delivery & Assembly** | **Accessories** | **Estimated Total** |
# |--------------------|--------------------|-------------------------|-----------------|---------------------|
# | Budget ($)         | $1,100–$1,500     | $100–$200              | $100–$200       | $1,300–$1,900       |
# | Mid-Range ($$)     | $2,400–$3,300     | $200–$400              | $200–$400       | $2,800–$4,100       |
# | Premium ($$$)      | $7,000+           | $500+                  | $500+           | $8,000+             |
#
# **Recommended Tier:**
# The mid-range tier offers the best balance between style, durability, and price. It ensures quality furnishings while staying within a reasonable budget.
#
# ---
#
# # **Furniture Breakdown & Pricing**
#
# ### **Living Room Furniture Pricing Options**
# | **Item**                   | **Budget ($)**  | **Mid-Range ($$)**  | **Premium ($$$)**       |
# |----------------------------|-----------------|---------------------|-------------------------|
# | **Sofa (3-Seater)**        | $300–$500       | $800–$1,200         | $2,000–$3,500           |
# | **Coffee Table**           | $75–$150        | $200–$400           | $600+                   |
# | **TV Console**             | $150–$300       | $400–$600           | $1,200+                 |
# | **Accent Chair**           | $100–$250       | $350–$600           | $1,000+                 |
# | **Chandelier/Light Fixture** | $75–$120      | $150–$300           | $500–$1,200             |
# | **Side Tables (2)**        | $50–$100 each   | $120–$250 each      | $400+ each              |
# | **Table Lamp**             | $30–$60         | $80–$150            | $300+                   |
# | **Curtains**               | $50–$100        | $150–$300           | $500+                   |
# | **Wall Art (Framed)**      | $20–$50         | $75–$200            | $300+                   |
#
# ---
#
# # **Where to Find Recommended Items**
#
# ### **Budget-Friendly Stores**
# - IKEA
# - Target
# - Wayfair
# - Amazon
#
# ### **Mid-Range Stores**
# - West Elm
# - Article
# - AllModern
# - CB2
#
# ### **Premium Stores**
# - Pottery Barn
# - Room & Board
# - Restoration Hardware (RH)
# - Design Within Reach
#
# ---
#
# # **Optional Services**
#
# ### **Delivery Options**
# 1. **Curbside Delivery**: $50–$100
# 2. **White-Glove Service**: $150–$400
#
# ### **Professional Assembly (Optional)**
# - Estimated Cost: $50–$200 per piece (via services like TaskRabbit).
#
# ---
#
# # **Total Estimate for a Mid-Range Tier Setup**
# **Furniture Total**: $2,850 (Approx.)
# **Delivery & Assembly**: $300
# **Accessories (Curtains, Rug, Decor)**: $250
# **Total Living Room Setup Cost**: **$3,400**
#
# ---
#
# # **Seasonal Recommendations**
# Consider scheduling your purchase during seasonal sales (e.g., January clearance, Memorial Day, 4th of July) to secure discounts for select furniture tiers.
#
# ---
#
# Let us know how we can further tailor this quote to fit your needs. Thank you for choosing us to help furnish your space!
