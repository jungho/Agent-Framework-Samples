# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.AzureAI\bin\Debug\net9.0\Microsoft.Agents.AI.AzureAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = "gpt-4o";

var imgPath ="../../files/home.png";

# %%
const string AgentName = "Vision-Agent";
const string AgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion";

# %%
using System.IO;

async Task<byte[]> OpenImageBytesAsync(string path)
{
	return await File.ReadAllBytesAsync(path);
}

var imageBytes = await OpenImageBytesAsync(imgPath);

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
var agentMetadata = await persistentAgentsClient.Administration.CreateAgentAsync(
    model: azure_foundry_model_id,
    name: AgentName,
    instructions: AgentInstructions);

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentMetadata.Value.Id);

# %%
AgentThread thread = agent.GetNewThread();

# %%
// Create the chat message with text and image content
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("Can you identify the furniture items in this image and suggest which ones would fit well in a modern living room?"), new DataContent(imageBytes, "image/png")
]);

# %%
Console.WriteLine(await agent.RunAsync(userMessage, thread));
# Out:
# This living room offers a modern design aesthetic, featuring both functional and stylish furniture. Here’s an identification of the furniture items and suggestions for which would fit well in a modern living room:
#
# ### **Identified Furniture Items**:
# 1. **Sectional Sofa** (White with decorative throw pillows)
#    - Clean lines with modern accents through neutral and bold-colored pillows.
# 2. **Coffee Table** (Round with a marble top)
#    - Minimalist design with sleek legs and a polished surface.
# 3. **TV Stand** (Wooden, low-height with storage compartments)
#    - Natural wood tones with open and closed storage for practical use.
# 4. **Accent Chair** (Dark blue, wingback style)
#    - A bold color detail and a cozy yet sophisticated design.
# 5. **Side Table** (Small round with sleek legs next to the TV stand)
#    - Features modern minimalism and functionality.
# 6. **Chandelier/Lighting Fixture** (Black frame with multiple exposed bulbs)
#    - Contemporary elegance, ideal for modern spaces.
# 7. **Floor Lamp** (With multiple spherical pendants near the window)
#    - Artistic and unique statement lighting piece.
# 8. **Curtains** (Dark gray and white sheer layers)
#    - Adds texture and softness while maintaining simplicity.
# 9. **Wall Art** (Minimalist animal-themed framed design)
#    - Provides subtle personality and character to the room.
#
# ---
#
# ### **Purchase Suggestions for a Modern Living Room**:
# 1. **Keep the sectional sofa as the centerpiece** – The neutral white color is versatile and works beautifully in a modern living room. Enhance it with decorative accent pillows in complementary hues (e.g., navy blue and gray tones).
# 2. **Coffee table with a marble top** – A perfect addition as it combines sleek design and subtle luxury. Marble is timeless and pairs well with modern aesthetics.
# 3. **TV Stand with storage compartments** – Opt for a similar wooden design with clean lines and a minimalist structure to maintain a modern yet functional vibe.
# 4. **Accent Chair** – The bold blue adds some color to the mostly neutral palette. Consider maintaining a similar pop of color or introducing a chair in velvet or textured fabric for added depth.
# 5. **Lighting Fixtures** – The black chandelier with exposed bulbs is ideal for a modern aesthetic. Likewise, the spherical floor lamp balances artistry and functionality. Make sure both lighting pieces are dimmable to control the mood.
# 6. **Curtains** – Maintain the sheer and dark gray combination, as it is both modern and practical in terms of privacy and light control.
# 7. **Wall Art** – Animal-themed art can add a personal touch, but you could go with abstract or geometric designs to emphasize modernity further.
#
# ### **Additional Suggestions**:
# - Consider adding a minimalist area rug—perhaps in textured gray or a pattern that ties in the blue and wood tones.
# - Keep accessories simple, like metallic decor or plants, to finish off the look without cluttering the space. For instance, adding greenery could complement the modern room ambiance.
#
# This design is already solid and stylish! The current setup, with some personalization tweaks, would work beautifully in any modern living room.
