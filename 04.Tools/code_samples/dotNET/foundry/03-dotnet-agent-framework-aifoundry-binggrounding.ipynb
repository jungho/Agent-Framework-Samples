# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "nuget: Azure.AI.Agents.Persistent, 1.2.0-beta.5"
#r "nuget: Azure.Identity, 1.15.0"
#r "nuget: System.Linq.Async, 6.0.3"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.Agents.Persistent, 1.2.0-beta.5</span></li><li><span>Azure.Identity, 1.15.0</span></li><li><span>System.Linq.Async, 6.0.3</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.AzureAI\bin\Debug\net9.0\Microsoft.Agents.AI.AzureAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.Linq;
using Azure.AI.Agents.Persistent;
using Azure.Identity;
using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../../.env");

# %%
var azure_foundry_endpoint = Environment.GetEnvironmentVariable("AZURE_AI_PROJECT_ENDPOINT") ?? throw new InvalidOperationException("AZURE_AI_PROJECT_ENDPOINT is not set.");
var azure_foundry_model_id = Environment.GetEnvironmentVariable("AZURE_AI_MODEL_DEPLOYMENT_NAME") ?? "gpt-4.1-mini";

# %%
const string AgentName = "Bing-Agent-Framework";
const string AgentInstructions = "You are an AI assistant that helps people find information.";

# %%
var persistentAgentsClient = new PersistentAgentsClient(azure_foundry_endpoint, new AzureCliCredential());

# %%
var conn_id = Environment.GetEnvironmentVariable("BING_CONNECTION_ID");

# %%
var bingGroudingConfig = new BingGroundingSearchConfiguration(conn_id);
// bingGroudingConfig.Count =5;
// bingGroudingConfig.Market= "en-US";
// bingGroudingConfig.SetLang= "en";

# %%
BingGroundingToolDefinition bingGroundingTool = new(
    new BingGroundingSearchToolParameters(
        [bingGroudingConfig]
    )
);

# %%
bingGroundingTool
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Azure.AI.Agents.Persistent.BingGroundingToolDefinition</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>BingGrounding</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Azure.AI.Agents.Persistent.BingGroundingSearchToolParameters</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>SearchConfigurations</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Azure.AI.Agents.Persistent.BingGroundingSearchConfiguration</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>ConnectionId</td><td><div class="dni-plaintext"><pre>/subscriptions/ee72069a-4726-4e1a-afe6-7f14e9b9d362/resourceGroups/rg-kinfeylo/providers/Microsoft.CognitiveServices/accounts/kinfeylo-aifoundry-proj-resource/projects/kinfeylo-aifoundry-project/connections/kinfeybingsearch</pre></div></td></tr><tr><td>Market</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>SetLang</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Count</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>Freshness</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
PersistentAgent agent =await persistentAgentsClient.Administration.CreateAgentAsync(
    model: azure_foundry_model_id,
    name: "bing-search-agent",
    instructions: "Use the bing grounding tool to answer questions.",
    tools: [bingGroundingTool]
);

# %%
string agentId = agent.Id;

# %%
agentId
# Out:
# asst_vfiOhmkusGhBF8FIhbUVJzOs

# %%
AIAgent agent = await persistentAgentsClient.GetAIAgentAsync(agentId);

# %%
AgentThread thread = agent.GetNewThread();

# %%
ChatMessage userMessage = new ChatMessage(ChatRole.User, [
	new TextContent("Could you please describe the workshop according to the link https://github.com/kinfey/GHCAgentWorkshop?")
]);

# %%
var result = await agent.RunAsync(userMessage, thread);

# %%
result
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop from the link you provided is designed to help participants create GitHub Copilot applications using a zero-code approach, making it accessible for everyone to manage projects with AI assistance. The workshop is structured into multiple experiments and labs, focusin...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Messages</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop from the link you provided is designed to help participants create GitHub Copilot applications using a zero-code approach, making it accessible for everyone to manage projects with AI assistance. The workshop is structured into multiple experiments and labs, focusin...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AuthorName</td><td><div class="dni-plaintext"><pre>asst_vfiOhmkusGhBF8FIhbUVJzOs</pre></div></td></tr><tr><td>CreatedAt</td><td><span>2025-09-30 14:35:35Z</span></td></tr><tr><td>Role</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>assistant</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>assistant</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Text</td><td><div class="dni-plaintext"><pre>The GitHub Copilot Agent Workshop from the link you provided is designed to help participants create GitHub Copilot applications using a zero-code approach, making it accessible for everyone to manage projects with AI assistance. The workshop is structured into multiple experiments and labs, focusing on different capabilities of GitHub Copilot and its Agent Mode.
#
# Key points about the workshop:
#
# - It requires participants to have a GitHub account and to fork and clone the workshop repository.
#
# - Participants should have Python 3.10.8+ (preferably installed via Miniforge) and Visual Studio Code Insider with the Python extension installed.
#
# - The workshop uses the free version of GitHub Copilot.
#
# - The workshop content includes multiple experiments such as:
#   1. Experiment 1: Retrieval-Augmented Generation (RAG) applications, exploring GitHub Copilot model capabilities and using Agent Mode to create Copilot application frontends and call GitHub Models.
#   2. Experiment 2: Stock analysis application, including generating simulated data and building UI with both frontend and backend components.
#   3. Experiment 3: Experience with GPT-5 and application deployment, including creating a lottery wheel app using Agent Mode and deploying via GitHub Pages.
#
# - The workshop provides step-by-step guidance on enabling Agent Mode in GitHub Copilot Chat, creating projects, and coding applications in HTML, JavaScript, and CSS with features such as responsive design, multi-language support, animations, and more.
#
# - It aims to give hands-on experience in project architecture, coding, and deployment using AI tools.
#
# Overall, the workshop is designed to teach users how to leverage GitHub Copilot&#39;s advanced AI capabilities (including GPT-5) to build, optimize, and deploy applications effectively with practical coding exercises. It emphasizes iterative improvement and user engagement with AI-enabled development tools.
#
# If you want a detailed breakdown or specific steps of any of the experiments or labs, I can provide that as well.【3:0†source】【3:3†source】【3:4†source】</pre></div></td></tr><tr><td>Contents</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>The GitHub Copilot Agent Workshop from the link you provided is designed to help participants create GitHub Copilot applications using a zero-code approach, making it accessible for everyone to manage projects with AI assistance. The workshop is structured into multiple experiments and labs, focusin...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Text</td><td><div class="dni-plaintext"><pre>The GitHub Copilot Agent Workshop from the link you provided is designed to help participants create GitHub Copilot applications using a zero-code approach, making it accessible for everyone to manage projects with AI assistance. The workshop is structured into multiple experiments and labs, focusing on different capabilities of GitHub Copilot and its Agent Mode.
#
# Key points about the workshop:
#
# - It requires participants to have a GitHub account and to fork and clone the workshop repository.
#
# - Participants should have Python 3.10.8+ (preferably installed via Miniforge) and Visual Studio Code Insider with the Python extension installed.
#
# - The workshop uses the free version of GitHub Copilot.
#
# - The workshop content includes multiple experiments such as:
#   1. Experiment 1: Retrieval-Augmented Generation (RAG) applications, exploring GitHub Copilot model capabilities and using Agent Mode to create Copilot application frontends and call GitHub Models.
#   2. Experiment 2: Stock analysis application, including generating simulated data and building UI with both frontend and backend components.
#   3. Experiment 3: Experience with GPT-5 and application deployment, including creating a lottery wheel app using Agent Mode and deploying via GitHub Pages.
#
# - The workshop provides step-by-step guidance on enabling Agent Mode in GitHub Copilot Chat, creating projects, and coding applications in HTML, JavaScript, and CSS with features such as responsive design, multi-language support, animations, and more.
#
# - It aims to give hands-on experience in project architecture, coding, and deployment using AI tools.
#
# Overall, the workshop is designed to teach users how to leverage GitHub Copilot&#39;s advanced AI capabilities (including GPT-5) to build, optimize, and deploy applications effectively with practical coding exercises. It emphasizes iterative improvement and user engagement with AI-enabled development tools.
#
# If you want a detailed breakdown or specific steps of any of the experiments or labs, I can provide that as well.【3:0†source】【3:3†source】【3:4†source】</pre></div></td></tr><tr><td>Annotations</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>RawRepresentation</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>AdditionalProperties</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>MessageId</td><td><div class="dni-plaintext"><pre>run_vm4HEI32Mgzmkxt1zsOxVXeL</pre></div></td></tr><tr><td>RawRepresentation</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>AdditionalProperties</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Text</td><td><div class="dni-plaintext"><pre>The GitHub Copilot Agent Workshop from the link you provided is designed to help participants create GitHub Copilot applications using a zero-code approach, making it accessible for everyone to manage projects with AI assistance. The workshop is structured into multiple experiments and labs, focusing on different capabilities of GitHub Copilot and its Agent Mode.
#
# Key points about the workshop:
#
# - It requires participants to have a GitHub account and to fork and clone the workshop repository.
#
# - Participants should have Python 3.10.8+ (preferably installed via Miniforge) and Visual Studio Code Insider with the Python extension installed.
#
# - The workshop uses the free version of GitHub Copilot.
#
# - The workshop content includes multiple experiments such as:
#   1. Experiment 1: Retrieval-Augmented Generation (RAG) applications, explorin
