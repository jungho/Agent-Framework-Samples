# %%
from agent_framework.azure import AzureAIAgentClient
from agent_framework import ChatMessage, DataContent, Role, TextContent

from azure.identity.aio import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
AgentName = "Vision-Agent"
AgentInstructions = "You are my furniture sales consultant, you can find different furniture elements from the pictures and give me a purchase suggestion"

# %%
async with (
        AzureCliCredential() as credential,
        AzureAIAgentClient(async_credential=credential) as chat_client,
    ):
    
        agent   = chat_client.create_agent(
            instructions=(
            AgentName
            ),
            name=AgentInstructions,
        )

        image_path = "../../files/home.png"
        with open(image_path, "rb") as image_file:
            image_b64 = base64.b64encode(image_file.read()).decode()
        image_uri = f"data:image/png;base64,{image_b64}"
        message = ChatMessage(
                role=Role.USER,
                contents=[
                    TextContent(text="Please find the relevant furniture according to the image and give the corresponding price for each piece of furniture"),
                    DataContent(uri=image_uri, media_type="image/png")
                ]
        )
        # response = agent.run_stream(message)
        first_result = await agent.run(message)
        
        print(f"Agent: {first_result.text}")
# Out:
# Agent: I can't access the internet or browse for specific products, but I can help you identify common furniture items in the room and provide a general price range based on typical costs.
#
# Here are the pieces of furniture visible in the image and their estimated price ranges:
#
# 1. **Sofa**: The large white sofa with pillows could range from **$500 to $2,000**, depending on the brand, material, and design.
#
# 2. **Coffee Table**: The round coffee table in front of the sofa might cost between **$150 and $600** based on its materials and style.
#
# 3. **TV Stand/Media Console**: The wooden unit under the TV can be priced between **$200 and $800**, depending on the quality and craftsmanship.
#
# 4. **Chandelier**: The hanging light fixture (chandelier) can range from **$100 to $500**, influenced by the design and materials used.
#
# 5. **Accent Chair**: The blue accent chair could be priced between **$150 and $600**, again depending on the design and brand.
#
# 6. **Side Table**: The small side table next to the sofa might cost between **$100 and $300** based on its materials.
#
# 7. **Decorative Items**: Items like vases, books, or small décor objects vary widely, but a rough estimate could be around **$20 to $100 each**, depending on the specifics.
#
# For precise pricing, consider checking furniture retailers' websites or visiting local furniture stores.
