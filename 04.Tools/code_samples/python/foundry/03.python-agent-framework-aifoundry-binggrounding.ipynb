# %%
from agent_framework.azure import AzureAIAgentClient
from agent_framework import ChatMessage, HostedWebSearchTool,Role, TextContent,HostedCodeInterpreterTool

from azure.identity.aio import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
AgentName = "Search-Agent"
AgentInstructions = "You are an AI assistant that helps people find information."

# %%
async with (
        AzureCliCredential() as credential,
        AzureAIAgentClient(async_credential=credential) as chat_client,
    ):
    
        agent   = chat_client.create_agent(
            instructions=(
            AgentName
            ),
            name=AgentInstructions,
            tools=[HostedWebSearchTool()],
        )
        message = ChatMessage(
                role=Role.USER,
                contents=[
                    TextContent(text="Could you please describe the workshop according to the link https://github.com/kinfey/GHCAgentWorkshop?")
                ]
        )
        # response = agent.run_stream(message)
        first_result = await agent.run(message)
        
        print(f"Agent: {first_result.text}")
# Out:
# Agent: The GitHub repository at https://github.com/kinfey/GHCAgentWorkshop hosts the "GitHub Copilot Agent Workshop." This workshop aims to guide participants in creating Copilot applications with zero coding, leveraging AI assistance to make everyone a project manager. The workshop primarily uses GitHub Copilot and its new Agent mode that enables direct project creation from requirements.
#
# The workshop setup requires the following:
# - A GitHub account
# - Forking and cloning the repository
# - Python 3.10.8+ (Miniforge recommended)
# - Visual Studio Code Insider edition with the Python extension
# - Free GitHub Copilot access
#
# The workshop is organized into three main experiments:
#
# 1. **Experiment 1: RAG Application**
#    - Understand GitHub Copilot model capabilities
#    - Explore Agent mode within GitHub Copilot Edit mode
#    - Create a Copilot application frontend using Agent mode
#    - Call GitHub Models through the Copilot Agent
#
# 2. **Experiment 2: Stock Analysis**
#    - Generate simulated stock data with Copilot Agent
#    - Build a stock UI with Copilot Agent
#    - Construct both frontend and backend for the stock app
#
# 3. **Experiment 3: GPT-5 Experience and Application Deployment**
#    - Learn about and use GPT-5 model in GitHub Copilot
#    - Create a lottery wheel app using Agent mode
#    - Deploy the app through GitHub Pages
#
# Additional resources and links are provided, such as free GitHub Copilot access, information on GitHub Models, and related blog articles to deepen understanding.
#
# In summary, the workshop offers a structured, hands-on approach to experience advanced AI-assisted coding and project creation using GitHub Copilot's Agent mode, from concept through deployment, targeting both beginners and intermediate users interested in AI ergonomics in software development.【3:0†source】
