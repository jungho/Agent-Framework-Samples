# %%
#r "nuget: Microsoft.Extensions.AI, 9.9.0"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI, 9.9.0</span></li></ul></div></div>

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI.OpenAI\bin\Debug\net9.0\Microsoft.Agents.AI.OpenAI.dll"

# %%
#r "C:\Users\kinfeylo\Documents\Agent\agent-framework\dotnet\src\Microsoft.Agents.AI\bin\Debug\net9.0\Microsoft.Agents.AI.dll"

# %%
#r "nuget: Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Extensions.AI.OpenAI, 9.9.0-preview.1.25458.4</span></li></ul></div></div>

# %%
#r "nuget: DotNetEnv, 3.1.1"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetEnv, 3.1.1</span></li></ul></div></div>

# %%
using System;
using System.ComponentModel;
using System.ClientModel;

using Microsoft.Extensions.AI;
using Microsoft.Agents.AI;
using OpenAI;

# %%
 using DotNetEnv;

# %%
Env.Load("../../../.env");

# %%
[Description("Provides a random vacation destination.")]
static string GetRandomDestination()
{
    var destinations = new List<string>
    {
        "Paris, France",
        "Tokyo, Japan",
        "New York City, USA",
        "Sydney, Australia",
        "Rome, Italy",
        "Barcelona, Spain",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bangkok, Thailand",
        "Vancouver, Canada"
    };

    var random = new Random();
    int index = random.Next(destinations.Count);
    return destinations[index];
}

# %%
var github_endpoint = Environment.GetEnvironmentVariable("GITHUB_ENDPOINT") ?? throw new InvalidOperationException("GITHUB_ENDPOINT is not set.");
var github_model_id = Environment.GetEnvironmentVariable("GITHUB_MODEL_ID") ?? "gpt-4o-mini";
var github_token = Environment.GetEnvironmentVariable("GITHUB_TOKEN") ?? throw new InvalidOperationException("GITHUB_TOKEN is not set.");

# %%
var openAIOptions = new OpenAIClientOptions()
{
    Endpoint= new Uri(github_endpoint)
};

# %%
var openAIClient = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions);

# %%
AIAgent agent = new OpenAIClient(new ApiKeyCredential(github_token), openAIOptions).GetChatClient(github_model_id).CreateAIAgent(
    instructions:"You are a helpful AI Agent that can help plan vacations for customers at random destinations", tools: [AIFunctionFactory.Create((Func<string>)GetRandomDestination)]);

# %%
AgentThread thread = agent.GetNewThread();

# %%
Console.WriteLine(await agent.RunAsync("Plan me a day trip",thread));
# Out:
# How about a day trip in Tokyo, Japan? Here's a suggested itinerary:
#
# ### Morning
# - **Start with Breakfast:** Enjoy a traditional Japanese breakfast at a local café. Try grilled fish, miso soup, and rice.
# - **Visit Senso-ji Temple:** Explore Tokyo's oldest temple located in Asakusa. Don't forget to stroll through Nakamise Street for some souvenirs and snacks.
#
# ### Late Morning
# - **Walk through Ueno Park:** Head to Ueno Park, famous for its cherry blossoms (in spring). You can visit museums or just relax in the park.
#
# ### Lunch
# - **Try Tsukiji Outer Market:** Enjoy fresh sushi or other seafood delicacies at this iconic food market.
#
# ### Afternoon
# - **Explore Akihabara:** Known for its electronics shops and otaku culture, spend some time browsing through anime and gadget shops.
# - **Visit the Meiji Shrine:** Take a peaceful walk to the tranquil Meiji Shrine surrounded by a lush forest.
#
# ### Evening
# - **Dinner in Shibuya:** Head to Shibuya to enjoy a lively dinner. You can try ramen or izakaya (Japanese-style pub).
# - **Witness the Shibuya Crossing:** Experience the bustling energy of one of the busiest pedestrian crossings in the world.
#
# ### Optional Night Activity
# - **Tokyo Tower or Tokyo Skytree:** End your day with breathtaking views of the Tokyo skyline at either Tokyo Tower or Tokyo Skytree.
#
# ### Travel Tips
# - **Transportation:** Use the subway; it's efficient and covers all major attractions.
# - **Etiquette:** Be respectful in places like temples and shrines, and remember to take your shoes off where required.
#
# Enjoy your day trip in Tokyo!

# %%
Console.WriteLine(await agent.RunAsync("I don't like that destination. Plan me another vacation.",thread));
# Out:
# How about a vacation in Bangkok, Thailand? Here's a suggested itinerary for an exciting day:
#
# ### Morning
# - **Breakfast at a Local Café:** Start your day with a traditional Thai breakfast, such as jok (rice porridge) or a Thai-style omelette.
# - **Visit the Grand Palace:** Explore the stunning Grand Palace, home to the Emerald Buddha. Make sure to dress modestly!
#
# ### Late Morning
# - **Wat Pho (Temple of the Reclining Buddha):** Just a short walk from the Grand Palace, visit Wat Pho to see the impressive reclining Buddha statue.
#
# ### Lunch
# - **Street Food Adventure:** Head to a local street market to sample delicious Thai street food. Don't miss out on pad thai or som tam (papaya salad).
#
# ### Afternoon
# - **Take a Boat Ride on Chao Phraya River:** Enjoy a boat trip along the river, with views of various temples and buildings. You can hop on a ferry to visit different attractions.
# - **Explore Khao San Road:** Spend some time walking around this vibrant area known for its backpacker vibe, shops, and food stalls.
#
# ### Evening
# - **Dinner at a Riverside Restaurant:** Dine at a restaurant along the river for a scenic view while enjoying authentic Thai cuisine.
# - **Visit Asiatique:** End the day at this night market, which features shopping, dining, and entertainment by the riverside.
#
# ### Optional Night Activity
# - **See a Muay Thai Fight:** Experience the thrill of a live Muay Thai boxing match at one of the local stadiums.
#
# ### Travel Tips
# - **Transportation:** Utilize the BTS Skytrain or riverboats to navigate the city easily.
# - **Stay Hydrated:** Bangkok can be hot and humid, so make sure to drink plenty of water.
#
# Enjoy your adventure in Bangkok!
